# %% [markdown]
# # **Sport Participation in the EU**: Demographic Trends and Personal Drivers

# %% [markdown]
# ## Initialisation

# %% [markdown]
# ### Import nessecary labrires and download data

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df_init = pd.read_csv('data/output.csv')
df_init.head()
# Out:
#    studyno1  studyno2                  doi             version  edition  \
# 0      7888      7888  doi:10.4232/1.14055  1.0.0 (2022-12-21)        1
# 1      7888      7888  doi:10.4232/1.14055  1.0.0 (2022-12-21)        1
# 2      7888      7888  doi:10.4232/1.14055  1.0.0 (2022-12-21)        1
# 3      7888      7888  doi:10.4232/1.14055  1.0.0 (2022-12-21)        1
# 4      7888      7888  doi:10.4232/1.14055  1.0.0 (2022-12-21)        1
#
#    survey  respondent_serial  serialid    uniqid  tnscntry  ...  w9       w10  \
# 0     973                  6         1  20000001         2  ... NaN  0.830778
# 1     973                 12         2  20000002         2  ... NaN  0.830519
# 2     973                 18         3  20000003         2  ... NaN  0.714949
# 3     973                 23         4  20000004         2  ... NaN  0.904568
# 4     973                 27         5  20000005         2  ... NaN  0.677808
#
#         w11       w85  w86  w13  w94       w14       w22       w92
# 0  0.274903  0.353595  NaN  NaN  NaN  0.373504  0.383012  0.394492
# 1  0.274817  0.353484  NaN  NaN  NaN  0.373387  0.382892  0.394369
# 2  0.236575  0.304296  NaN  NaN  NaN  0.321429  0.329612  0.339491
# 3  0.299320  0.385001  NaN  NaN  NaN  0.406679  0.417031  0.429531
# 4  0.224285  0.288488  NaN  NaN  NaN  0.304731  0.312488  0.321855
#
# [5 rows x 501 columns]

# %% [markdown]
# ### Delete columns that don't conect with research

# %% [markdown]
# columns that started from qa, qc, d, s are questions about politics and social life
#
# We need only data are started from qb (these are about sport), d10 (it is gender) and date are about locations and time

# %%
starts_unnecessary_columns = ['studyno1', 'isocntry', 'country', 'w','studyno2','polintr','netuse','capi_cawi','version','edition','qa', 'qc', 'd', 's']
def filter_unnecessary_columns(col):
    for i in starts_unnecessary_columns:
        if col.startswith(i) and not col.startswith('d10') and not col.startswith('d11'):
            return True
    return False

# %%
df_init.head()
# Out:
#    studyno1  studyno2                  doi             version  edition  \
# 0      7888      7888  doi:10.4232/1.14055  1.0.0 (2022-12-21)        1
# 1      7888      7888  doi:10.4232/1.14055  1.0.0 (2022-12-21)        1
# 2      7888      7888  doi:10.4232/1.14055  1.0.0 (2022-12-21)        1
# 3      7888      7888  doi:10.4232/1.14055  1.0.0 (2022-12-21)        1
# 4      7888      7888  doi:10.4232/1.14055  1.0.0 (2022-12-21)        1
#
#    survey  respondent_serial  serialid    uniqid  tnscntry  ...  w9       w10  \
# 0     973                  6         1  20000001         2  ... NaN  0.830778
# 1     973                 12         2  20000002         2  ... NaN  0.830519
# 2     973                 18         3  20000003         2  ... NaN  0.714949
# 3     973                 23         4  20000004         2  ... NaN  0.904568
# 4     973                 27         5  20000005         2  ... NaN  0.677808
#
#         w11       w85  w86  w13  w94       w14       w22       w92
# 0  0.274903  0.353595  NaN  NaN  NaN  0.373504  0.383012  0.394492
# 1  0.274817  0.353484  NaN  NaN  NaN  0.373387  0.382892  0.394369
# 2  0.236575  0.304296  NaN  NaN  NaN  0.321429  0.329612  0.339491
# 3  0.299320  0.385001  NaN  NaN  NaN  0.406679  0.417031  0.429531
# 4  0.224285  0.288488  NaN  NaN  NaN  0.304731  0.312488  0.321855
#
# [5 rows x 501 columns]

# %%
df = df_init.drop(columns=[col for col in df_init.columns if filter_unnecessary_columns(col)])
df.head()
# Out:
#    respondent_serial    uniqid  tnscntry  q1_1  q1_2  q1_3  q1_4  q1_5  q1_6  \
# 0                  6  20000001         2     0     0     0     0     0     0
# 1                 12  20000002         2     0     0     0     0     0     0
# 2                 18  20000003         2     0     0     0     0     0     0
# 3                 23  20000004         2     0     0     0     0     0     0
# 4                 27  20000005         2     0     0     0     0     0     0
#
#    q1_7  ...  region_luxembourg  region_malta  region_netherlands  \
# 0     0  ...                NaN           NaN                 NaN
# 1     0  ...                NaN           NaN                 NaN
# 2     0  ...                NaN           NaN                 NaN
# 3     0  ...                NaN           NaN                 NaN
# 4     0  ...                NaN           NaN                 NaN
#
#    region_poland  region_portugal  region_romania  region_slovenia  \
# 0            NaN              NaN             NaN              NaN
# 1            NaN              NaN             NaN              NaN
# 2            NaN              NaN             NaN              NaN
# 3            NaN              NaN             NaN              NaN
# 4            NaN              NaN             NaN              NaN
#
#    region_slovakia  region_spain  region_sweden
# 0              NaN           NaN            NaN
# 1              NaN           NaN            NaN
# 2              NaN           NaN            NaN
# 3              NaN           NaN            NaN
# 4              NaN           NaN            NaN
#
# [5 rows x 156 columns]

# %% [markdown]
# ### Show all columns

# %%
def show_columns(columns):
    for i in range(0, len(columns), 3):
        print(columns[i:i+3])

# %%
show_columns(list(df.columns))
# Out:
# ['respondent_serial', 'uniqid', 'tnscntry']
# ['q1_1', 'q1_2', 'q1_3']
# ['q1_4', 'q1_5', 'q1_6']
# ['q1_7', 'q1_8', 'q1_9']
# ['q1_10', 'q1_11', 'q1_12']
# ['q1_13', 'q1_14', 'q1_15']
# ['q1_16', 'q1_17', 'q1_18']
# ['q1_19', 'q1_20', 'q1_21']
# ['q1_22', 'q1_23', 'q1_24']
# ['q1_25', 'q1_26', 'q1_27']
# ['q1_28', 'q1_40', 'q1_41']
# ['d11', 'd11r1', 'd11r2']
# ['qb1', 'qb1r', 'qb2']
# ['qb2r', 'qb3', 'qb3r']
# ['qb4', 'qb5', 'qb5r']
# ['qb6', 'qb7', 'qb7r']
# ['qb8', 'qb9', 'qb9r']
# ['qb10_1', 'qb10_2', 'qb10_3']
# ['qb10_4', 'qb10_5', 'qb10_6']
# ['qb10_7', 'qb10_8', 'qb10_9']
# ['qb10_10', 'qb11_1', 'qb11_2']
# ['qb11_3', 'qb11_4', 'qb11_5']
# ['qb11_6', 'qb11_7', 'qb11_8']
# ['qb11_9', 'qb11_10', 'qb11_11']
# ['qb11_12', 'qb11_13', 'qb11_14']
# ['qb11_15', 'qb11_16', 'qb11_17']
# ['qb12_1', 'qb12_2', 'qb12_3']
# ['qb12_4', 'qb12_5', 'qb12_6']
# ['qb13_1', 'qb13_2', 'qb13_3']
# ['qb14_1', 'qb14_2', 'qb14_3']
# ['qb14_4', 'qb14_5', 'qb14_6']
# ['qb14_7', 'qb14_8', 'qb14_9']
# ['qb14_10', 'qb14_11', 'qb14_12']
# ['qb14_13', 'qb15_1', 'qb15_2']
# ['qb15_3', 'qb15_4', 'qb15_5']
# ['qb15_6', 'qb16', 'qb16r']
# ['qb17_1', 'qb17_2', 'qb17_3']
# ['qb17_4', 'qb17_5', 'qb17_6']
# ['qb17_7', 'qb18', 'qb19']
# ['qb20_1', 'qb20_2', 'qb20_3']
# ['qb21', 'd10', 'p1']
# ['p2', 'p3', 'p4']
# ['p5', 'p6', 'p13']
# ['region_austria', 'region_belgium', 'region_bulgaria']
# ['region_croatia', 'region_cyprus', 'region_czechia']
# ['region_denmark', 'region_germany', 'region_estonia']
# ['region_finland', 'region_france', 'region_greece']
# ['region_hungary', 'region_ireland', 'region_italy']
# ['region_latvia', 'region_lithuania', 'region_luxembourg']
# ['region_malta', 'region_netherlands', 'region_poland']
# ['region_portugal', 'region_romania', 'region_slovenia']
# ['region_slovakia', 'region_spain', 'region_sweden']

# %% [markdown]
# ### Rename columns

# %%
renamed_columns = {
    'tnscntry': 'respondent_country',
    'q1_1': 'n_BELGIUM',
    'q1_2': 'n_DENMARK',
    'q1_3': 'n_GERMANY',
    'q1_4': 'n_GREECE',
    'q1_5': 'n_SPAIN',
    'q1_6': 'n_FRANCE',
    'q1_7': 'n_IRELAND',
    'q1_8': 'n_ITALY',
    'q1_9': 'n_LUXEMBOURG',
    'q1_10': 'n_NETHERLANDS',
    'q1_11': 'n_PORTUGAL',
    'q1_12': 'n_UNITED KINGDOM',
    'q1_13': 'n_AUSTRIA',
    'q1_14': 'n_SWEDEN',
    'q1_15': 'n_FINLAND',
    'q1_16': 'n_CYPRUS',
    'q1_17': 'n_CZECH REPUBLIC',
    'q1_18': 'n_ESTONIA',
    'q1_19': 'n_HUNGARY',
    'q1_20': 'n_LATVIA',
    'q1_21': 'n_LITHUANIA',
    'q1_22': 'n_MALTA',
    'q1_23': 'n_POLAND',
    'q1_24': 'n_SLOVAKIA',
    'q1_25': 'n_SLOVENIA',
    'q1_26': 'n_BULGARIA',
    'q1_27': 'n_ROMANIA',
    'q1_28': 'n_CROATIA',
    'q1_40': 'n_OTHER COUNTRIES',
    'q1_41': 'n_DK',
    'd11': 'age',
    'd11r1': 'age category',
    'd11r2': 'age large category',
    'qb1': 'SPORT ACTIVITY FREQ',
    'qb1r': 'SPORT ACTIVITY FREQ RECODE',
    'qb2': 'PHYS ACTIVITY FREQ',
    'qb2r': 'PHYS ACTIVITY FREQ RECODE',
    'qb3': 'VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK',
    'qb3r': 'VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK RECODE',
    'qb4': 'VIGOROUS PHYS ACTIVITY - HOW MUCH TIME',
    'qb5': 'MODERATE PHYS ACTIVITY - DAYS LAST WEEK',
    'qb5r': 'MODERATE PHYS ACTIVITY - DAYS LAST WEEK RECODE',
    'qb6': 'MODERATE PHYS ACTIVITY - HOW MUCH TIME',
'qb7': 'WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK',
'qb7r': 'WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK RECODE',
'qb8': 'WALKED AT LEAST 10 MINUTES - HOW MUCH TIME',
'qb9': 'TIME SPENT SITTING',
'qb9r': 'TIME SPENT SITTING RECODE',
'qb10_1': 'SPORT ACTIVITY VENUE: FITNESS CENTER',
'qb10_2': 'SPORT ACTIVITY VENUE: SPORTS CLUB',
'qb10_3': 'SPORT ACTIVITY VENUE: SPORTS CENTER',
'qb10_4': 'SPORT ACTIVITY VENUE: SCHOOL/UNIVERSITY',
'qb10_5': 'SPORT ACTIVITY VENUE: AT WORK',
'qb10_6': 'SPORT ACTIVITY VENUE: AT HOME',
'qb10_7': 'SPORT ACTIVITY VENUE: ON THE WAY',
'qb10_8': 'SPORT ACTIVITY VENUE: PARK/OUTDOORS',
'qb10_9': 'SPORT ACTIVITY VENUE: ELSEWHERE (SPONT)',
'qb10_10': 'SPORT ACTIVITY VENUE: DK (SPONT)',
'qb11_1': 'SPORT ACTIVITY REASON: HEALTH IMPROVEMENT',
'qb11_2': 'SPORT ACTIVITY REASON: PHYSICAL APPEARANCE',
'qb11_3': 'SPORT ACTIVITY REASON: COUNTERACT AGING',
'qb11_4': 'SPORT ACTIVITY REASON: HAVE FUN',
'qb11_5': 'SPORT ACTIVITY REASON: RELAX',
'qb11_6': 'SPORT ACTIVITY REASON: BE WITH FRIENDS',
'qb11_7': 'SPORT ACTIVITY REASON: MAKE ACQUAINTANCES',
'qb11_8': 'SPORT ACTIVITY REASON: MEET OTHER CULTURES',
'qb11_9': 'SPORT ACTIVITY REASON: PHYSICAL PERFORMANCE',
'qb11_10': 'SPORT ACTIVITY REASON: FITNESS',
'qb11_11': 'SPORT ACTIVITY REASON: CONTROL WEIGHT',
'qb11_12': 'SPORT ACTIVITY REASON: SELF-ESTEEM',
'qb11_13': 'SPORT ACTIVITY REASON: NEW SKILLS',
'qb11_14': 'SPORT ACTIVITY REASON: SPIRIT OF COMPETITION',
'qb11_15': 'SPORT ACTIVITY REASON: SOCIAL INTEGRATION',
'qb11_16': 'SPORT ACTIVITY REASON: OTHER (SPONT)',
'qb11_17': 'SPORT ACTIVITY REASON: DK (SPONT)',
'qb12_1': 'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: STOPPED',
'qb12_2': 'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: LESS FREQUENTLY',
'qb12_3': 'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: SAME',
'qb12_4': 'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: MORE FREQUENTLY',
'qb12_5': 'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: PLAN MORE AFTER PANDEMIC',
'qb12_6': 'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: DK (SPONT)',
'qb13_1': 'SPORT - MANY OPPORTUNITIES IN AREA',
'qb13_2': 'SPORT - MANY OPPORTUNITIES BY LOCAL SPORTS CLUBS',
'qb13_3': 'SPORT - LOCAL AUTHORITY DOES NOT DO ENOUGH',
'qb14_1': 'NO SPORT ACTIVITY REASON: NO TIME',
'qb14_2': 'NO SPORT ACTIVITY REASON: TOO EXPENSIVE',
'qb14_3': 'NO SPORT ACTIVITY REASON: COMPETITIVITY',
'qb14_4': 'NO SPORT ACTIVITY REASON: NO INFRASTRUCTURE',
'qb14_5': 'NO SPORT ACTIVITY REASON: DISABILITY/ILLNESS',
'qb14_6': 'NO SPORT ACTIVITY REASON: NO FRIENDS',
'qb14_7': 'NO SPORT ACTIVITY REASON: FEEL DISCRIMINATED',
'qb14_8': 'NO SPORT ACTIVITY REASON: NO OPPORTUNITY W SAME GENDER',
'qb14_9': 'NO SPORT ACTIVITY REASON: LACK MOTIVATION',
'qb14_10': 'NO SPORT ACTIVITY REASON: RISK OF INJURIES',
'qb14_11': 'NO SPORT ACTIVITY REASON: ALREADY DOING (SPONT)',
'qb14_12': 'NO SPORT ACTIVITY REASON: OTHER (SPONT)',
'qb14_13': 'NO SPORT ACTIVITY REASON: DK (SPONT)',
'qb15_1': 'MEMBERSHIP: HEALTH/FITNESS CENTRE',
'qb15_2': 'MEMBERSHIP: SPORT CLUB',
'qb15_3': 'MEMBERSHIP: SOCIOCULTURAL CLUB',
'qb15_4': 'MEMBERSHIP: OTHER (SPONT)',
'qb15_5': 'MEMBERSHIP: NOT A MEMBER (SPONT)',
'qb15_6': 'MEMBERSHIP: DK (SPONT)',
'qb16': 'ATTENTION ON IMPACT OF SPORT ON ENVIRONMENT',
'qb16r': 'ATTENTION ON IMPACT OF SPORT ON ENVIRONMENT RECODE',
'qb17_1': 'SUSTAINABILITY ACTION OF SPORT ORG: USE GREEN ENERGY',
'qb17_2': 'SUSTAINABILITY ACTION OF SPORT ORG: INCREASE ENERGY EFFICIENCY',
'qb17_3': 'SUSTAINABILITY ACTION OF SPORT ORG: SUSTAINABLE TRANSPORTATION',
'qb17_4': 'SUSTAINABILITY ACTION OF SPORT ORG: CRITERIA FOR FOOD/CATERING',
'qb17_5': 'SUSTAINABILITY ACTION OF SPORT ORG: REDUCE WASTE',
'qb17_6': 'SUSTAINABILITY ACTION OF SPORT ORG: NONE AS FAR AS KNOWN',
'qb17_7': 'SUSTAINABILITY ACTION OF SPORT ORG: DK (SPONT)',
'qb18': 'SUPPORT OF GENDER EQUALITY IN SPORT ORG',
'qb19': 'KNOW CONTACT TO SPEAK TO IN SPORT ORG WHEN GENDER DISCRIMINATION',
'qb20_1': 'GENDER EQUALITY IN SPORT - FEMALE ROLE MODELS INSPIRING',
'qb20_2': 'GENDER EQUALITY IN SPORT - FOLLOW FEMALE/MALE SPORT EVENLY IN MEDIA',
'qb20_3': 'GENDER EQUALITY IN SPORT - MORE ATTENTION FOR GENDER BASED VIOLENCE',
'qb21': 'VOLUNTARY WORK IN SPORT - ENGAGED OR PLANNED NEXT TWO MONTHS',
'p1': 'DATE OF INTERVIEW',
'p2': 'TIME OF INTERVIEW',
'p3': 'DURATION OF INTERVIEW (SECONDS) ',
'p4': 'N OF PERSONS PRESENT DURING INTERVIEW',
'p5': 'RESPONDENT COOPERATION',
'p6': 'SIZE OF COMMUNITY',
'p13': 'LANGUAGE OF INTERVIEW (ALL LANGUAGES)',
'd10': 'GENDER',
    }

# %%
df = df.rename(columns=renamed_columns)
df.head()
# Out:
#    respondent_serial    uniqid  respondent_country  n_BELGIUM  n_DENMARK  \
# 0                  6  20000001                   2          0          0
# 1                 12  20000002                   2          0          0
# 2                 18  20000003                   2          0          0
# 3                 23  20000004                   2          0          0
# 4                 27  20000005                   2          0          0
#
#    n_GERMANY  n_GREECE  n_SPAIN  n_FRANCE  n_IRELAND  ...  region_luxembourg  \
# 0          0         0        0         0          0  ...                NaN
# 1          0         0        0         0          0  ...                NaN
# 2          0         0        0         0          0  ...                NaN
# 3          0         0        0         0          0  ...                NaN
# 4          0         0        0         0          0  ...                NaN
#
#    region_malta  region_netherlands  region_poland  region_portugal  \
# 0           NaN                 NaN            NaN              NaN
# 1           NaN                 NaN            NaN              NaN
# 2           NaN                 NaN            NaN              NaN
# 3           NaN                 NaN            NaN              NaN
# 4           NaN                 NaN            NaN              NaN
#
#    region_romania  region_slovenia  region_slovakia  region_spain  \
# 0             NaN              NaN              NaN           NaN
# 1             NaN              NaN              NaN           NaN
# 2             NaN              NaN              NaN           NaN
# 3             NaN              NaN              NaN           NaN
# 4             NaN              NaN              NaN           NaN
#
#    region_sweden
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 156 columns]

# %% [markdown]
# ## EDA

# %%
df.shape
# Out:
# (26569, 156)

# %%
columns = list(df.columns)
show_columns(columns)
# Out:
# ['respondent_serial', 'uniqid', 'respondent_country']
# ['n_BELGIUM', 'n_DENMARK', 'n_GERMANY']
# ['n_GREECE', 'n_SPAIN', 'n_FRANCE']
# ['n_IRELAND', 'n_ITALY', 'n_LUXEMBOURG']
# ['n_NETHERLANDS', 'n_PORTUGAL', 'n_UNITED KINGDOM']
# ['n_AUSTRIA', 'n_SWEDEN', 'n_FINLAND']
# ['n_CYPRUS', 'n_CZECH REPUBLIC', 'n_ESTONIA']
# ['n_HUNGARY', 'n_LATVIA', 'n_LITHUANIA']
# ['n_MALTA', 'n_POLAND', 'n_SLOVAKIA']
# ['n_SLOVENIA', 'n_BULGARIA', 'n_ROMANIA']
# ['n_CROATIA', 'n_OTHER COUNTRIES', 'n_DK']
# ['age', 'age category', 'age large category']
# ['SPORT ACTIVITY FREQ', 'SPORT ACTIVITY FREQ RECODE', 'PHYS ACTIVITY FREQ']
# ['PHYS ACTIVITY FREQ RECODE', 'VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK', 'VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK RECODE']
# ['VIGOROUS PHYS ACTIVITY - HOW MUCH TIME', 'MODERATE PHYS ACTIVITY - DAYS LAST WEEK', 'MODERATE PHYS ACTIVITY - DAYS LAST WEEK RECODE']
# ['MODERATE PHYS ACTIVITY - HOW MUCH TIME', 'WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK', 'WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK RECODE']
# ['WALKED AT LEAST 10 MINUTES - HOW MUCH TIME', 'TIME SPENT SITTING', 'TIME SPENT SITTING RECODE']
# ['SPORT ACTIVITY VENUE: FITNESS CENTER', 'SPORT ACTIVITY VENUE: SPORTS CLUB', 'SPORT ACTIVITY VENUE: SPORTS CENTER']
# ['SPORT ACTIVITY VENUE: SCHOOL/UNIVERSITY', 'SPORT ACTIVITY VENUE: AT WORK', 'SPORT ACTIVITY VENUE: AT HOME']
# ['SPORT ACTIVITY VENUE: ON THE WAY', 'SPORT ACTIVITY VENUE: PARK/OUTDOORS', 'SPORT ACTIVITY VENUE: ELSEWHERE (SPONT)']
# ['SPORT ACTIVITY VENUE: DK (SPONT)', 'SPORT ACTIVITY REASON: HEALTH IMPROVEMENT', 'SPORT ACTIVITY REASON: PHYSICAL APPEARANCE']
# ['SPORT ACTIVITY REASON: COUNTERACT AGING', 'SPORT ACTIVITY REASON: HAVE FUN', 'SPORT ACTIVITY REASON: RELAX']
# ['SPORT ACTIVITY REASON: BE WITH FRIENDS', 'SPORT ACTIVITY REASON: MAKE ACQUAINTANCES', 'SPORT ACTIVITY REASON: MEET OTHER CULTURES']
# ['SPORT ACTIVITY REASON: PHYSICAL PERFORMANCE', 'SPORT ACTIVITY REASON: FITNESS', 'SPORT ACTIVITY REASON: CONTROL WEIGHT']
# ['SPORT ACTIVITY REASON: SELF-ESTEEM', 'SPORT ACTIVITY REASON: NEW SKILLS', 'SPORT ACTIVITY REASON: SPIRIT OF COMPETITION']
# ['SPORT ACTIVITY REASON: SOCIAL INTEGRATION', 'SPORT ACTIVITY REASON: OTHER (SPONT)', 'SPORT ACTIVITY REASON: DK (SPONT)']
# ['COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: STOPPED', 'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: LESS FREQUENTLY', 'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: SAME']
# ['COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: MORE FREQUENTLY', 'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: PLAN MORE AFTER PANDEMIC', 'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: DK (SPONT)']
# ['SPORT - MANY OPPORTUNITIES IN AREA', 'SPORT - MANY OPPORTUNITIES BY LOCAL SPORTS CLUBS', 'SPORT - LOCAL AUTHORITY DOES NOT DO ENOUGH']
# ['NO SPORT ACTIVITY REASON: NO TIME', 'NO SPORT ACTIVITY REASON: TOO EXPENSIVE', 'NO SPORT ACTIVITY REASON: COMPETITIVITY']
# ['NO SPORT ACTIVITY REASON: NO INFRASTRUCTURE', 'NO SPORT ACTIVITY REASON: DISABILITY/ILLNESS', 'NO SPORT ACTIVITY REASON: NO FRIENDS']
# ['NO SPORT ACTIVITY REASON: FEEL DISCRIMINATED', 'NO SPORT ACTIVITY REASON: NO OPPORTUNITY W SAME GENDER', 'NO SPORT ACTIVITY REASON: LACK MOTIVATION']
# ['NO SPORT ACTIVITY REASON: RISK OF INJURIES', 'NO SPORT ACTIVITY REASON: ALREADY DOING (SPONT)', 'NO SPORT ACTIVITY REASON: OTHER (SPONT)']
# ['NO SPORT ACTIVITY REASON: DK (SPONT)', 'MEMBERSHIP: HEALTH/FITNESS CENTRE', 'MEMBERSHIP: SPORT CLUB']
# ['MEMBERSHIP: SOCIOCULTURAL CLUB', 'MEMBERSHIP: OTHER (SPONT)', 'MEMBERSHIP: NOT A MEMBER (SPONT)']
# ['MEMBERSHIP: DK (SPONT)', 'ATTENTION ON IMPACT OF SPORT ON ENVIRONMENT', 'ATTENTION ON IMPACT OF SPORT ON ENVIRONMENT RECODE']
# ['SUSTAINABILITY ACTION OF SPORT ORG: USE GREEN ENERGY', 'SUSTAINABILITY ACTION OF SPORT ORG: INCREASE ENERGY EFFICIENCY', 'SUSTAINABILITY ACTION OF SPORT ORG: SUSTAINABLE TRANSPORTATION']
# ['SUSTAINABILITY ACTION OF SPORT ORG: CRITERIA FOR FOOD/CATERING', 'SUSTAINABILITY ACTION OF SPORT ORG: REDUCE WASTE', 'SUSTAINABILITY ACTION OF SPORT ORG: NONE AS FAR AS KNOWN']
# ['SUSTAINABILITY ACTION OF SPORT ORG: DK (SPONT)', 'SUPPORT OF GENDER EQUALITY IN SPORT ORG', 'KNOW CONTACT TO SPEAK TO IN SPORT ORG WHEN GENDER DISCRIMINATION']
# ['GENDER EQUALITY IN SPORT - FEMALE ROLE MODELS INSPIRING', 'GENDER EQUALITY IN SPORT - FOLLOW FEMALE/MALE SPORT EVENLY IN MEDIA', 'GENDER EQUALITY IN SPORT - MORE ATTENTION FOR GENDER BASED VIOLENCE']
# ['VOLUNTARY WORK IN SPORT - ENGAGED OR PLANNED NEXT TWO MONTHS', 'GENDER', 'DATE OF INTERVIEW']
# ['TIME OF INTERVIEW', 'DURATION OF INTERVIEW (SECONDS) ', 'N OF PERSONS PRESENT DURING INTERVIEW']
# ['RESPONDENT COOPERATION', 'SIZE OF COMMUNITY', 'LANGUAGE OF INTERVIEW (ALL LANGUAGES)']
# ['region_austria', 'region_belgium', 'region_bulgaria']
# ['region_croatia', 'region_cyprus', 'region_czechia']
# ['region_denmark', 'region_germany', 'region_estonia']
# ['region_finland', 'region_france', 'region_greece']
# ['region_hungary', 'region_ireland', 'region_italy']
# ['region_latvia', 'region_lithuania', 'region_luxembourg']
# ['region_malta', 'region_netherlands', 'region_poland']
# ['region_portugal', 'region_romania', 'region_slovenia']
# ['region_slovakia', 'region_spain', 'region_sweden']

# %%
df.describe()
# Out:
#        respondent_serial        uniqid  respondent_country     n_BELGIUM  \
# count       26569.000000  2.656900e+04        26569.000000  26569.000000
# mean         1769.028680  2.095812e+08           20.956792      0.040724
# std          1614.011623  1.142877e+08           11.428358      0.197654
# min             1.000000  2.000000e+07            2.000000      0.000000
# 25%           673.000000  1.200258e+08           12.000000      0.000000
# 50%          1360.000000  1.900130e+08           19.000000      0.000000
# 75%          2276.000000  3.200190e+08           32.000000      0.000000
# max          8727.000000  4.200055e+08           42.000000      1.000000
#
#           n_DENMARK     n_GERMANY      n_GREECE       n_SPAIN      n_FRANCE  \
# count  26569.000000  26569.000000  26569.000000  26569.000000  26569.000000
# mean       0.037751      0.056796      0.039181      0.037224      0.040875
# std        0.190596      0.231456      0.194029      0.189313      0.198004
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#           n_IRELAND  ...  region_luxembourg  region_malta  region_netherlands  \
# count  26569.000000  ...         502.000000         504.0         1032.000000
# mean       0.035944  ...           2.601594           1.0            7.464147
# std        0.186154  ...           1.311943           0.0            3.039774
# min        0.000000  ...           1.000000           1.0            1.000000
# 25%        0.000000  ...           1.000000           1.0            5.000000
# 50%        0.000000  ...           3.000000           1.0            8.000000
# 75%        0.000000  ...           4.000000           1.0           10.000000
# max        1.000000  ...           4.000000           1.0           12.000000
#
#        region_poland  region_portugal  region_romania  region_slovenia  \
# count    1013.000000      1005.000000     1057.000000      1022.000000
# mean        7.269497         2.590050        4.240303         6.625245
# std         4.746272         1.395461        2.183132         3.616193
# min         1.000000         1.000000        1.000000         1.000000
# 25%         3.000000         1.000000        2.000000         2.000000
# 50%         6.000000         3.000000        4.000000         8.000000
# 75%        11.000000         4.000000        6.000000         9.000000
# max        16.000000         5.000000        8.000000        12.000000
#
#        region_slovakia  region_spain  region_sweden
# count      1010.000000   1006.000000    1038.000000
# mean          2.544554     10.485089       1.815029
# std           1.049090      4.463815       0.769780
# min           1.000000      1.000000       1.000000
# 25%           2.000000      8.000000       1.000000
# 50%           2.000000     12.000000       2.000000
# 75%           4.000000     15.000000       2.000000
# max           4.000000     17.000000       3.000000
#
# [8 rows x 156 columns]

# %%
sum(df.isnull().sum())
# Out:
# 1125418

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Functions used for processing

# %%
def show_columns_info(column_name):
    print(df[column_name].value_counts())
    print(f'Null values: {df[column_name].isnull().sum()}')
    print(f'Type values: {df[column_name].dtype}')
    print()

# %%
def replace_values(column_name, data_map):
    df[column_name] = df[column_name].replace(data_map)
    show_columns_info(column_name)

# %%
def multiple_replace(columns_map):
    for col,data in columns_map.items():
        replace_values(col, data)

# %% [markdown]
# ### Identification user data

# %% [markdown]
# #### Show information about all data

# %%
c_columns = ['respondent_serial', 'uniqid', 'respondent_country']

for i in c_columns:
    show_columns_info(i)
# Out:
# respondent_serial
# 1148    17
# 1364    17
# 323     17
# 756     16
# 1251    16
#         ..
# 8631     1
# 8632     1
# 8633     1
# 8634     1
# 8635     1
# Name: count, Length: 5816, dtype: int64
# Null values: 0
# Type values: int64
#
# uniqid
# 150026578    1
# 20000001     1
# 20000002     1
# 20000003     1
# 20000004     1
#             ..
# 20000013     1
# 20000014     1
# 20000015     1
# 20000016     1
# 20000017     1
# Name: count, Length: 26569, dtype: int64
# Null values: 0
# Type values: int64
#
# respondent_country
# 3     1101
# 9     1073
# 33    1057
# 35    1043
# 4     1039
# 29    1032
# 12    1030
# 18    1025
# 36    1022
# 21    1020
# 41    1015
# 13    1014
# 31    1013
# 25    1013
# 16    1012
# 19    1011
# 37    1010
# 17    1008
# 14    1006
# 2     1005
# 32    1005
# 15    1004
# 11    1004
# 23    1002
# 28     504
# 7      503
# 24     502
# 42     496
# Name: count, dtype: int64
# Null values: 0
# Type values: int64

# %% [markdown]
# #### Respondent country data to replace

# %%
res_map = {
    1: 'Albania',
    2: 'Austria',
    3: 'Belgium',
    4: 'Bulgaria',
    5: 'Bosnia and Herzegovina',
    6: 'Switzerland',
    7: 'Cyprus',
    8: 'Cyprus - CY',
    9: 'Czech Republic',
    10: 'Germany',
    11: 'Denmark',
    12: 'Estonia',
    13: 'Greece',
    14: 'Spain',
    15: 'Finland',
    16: 'France',
    17: 'Croatia',
    18: 'Hungary',
    19: 'Ireland',
    20: 'Iceland',
    21: 'Italy',
    22: 'Kosovo',
    23: 'Lithuania',
    24: 'Luxemburg',
    25: 'Latvia',
    26: 'Montenegro',
    27: 'Macedonia',
    28: 'Malta',
    29: 'Netherlands',
    30: 'Norway',
    31: 'Poland',
    32: 'Portugal',
    33: 'Romania',
    34: 'Serbia',
    35: 'Sweden',
    36: 'Slovenia',
    37: 'Slovakia',
    38: 'Turkey',
    39: 'United Kingdom',
    40: 'None',
    41: 'Germany',
    42: 'Germany'
}

replace_values('respondent_country', res_map)
# Out:
# respondent_country
# Germany           1511
# Belgium           1101
# Czech Republic    1073
# Romania           1057
# Sweden            1043
# Bulgaria          1039
# Netherlands       1032
# Estonia           1030
# Hungary           1025
# Slovenia          1022
# Italy             1020
# Greece            1014
# Latvia            1013
# Poland            1013
# France            1012
# Ireland           1011
# Slovakia          1010
# Croatia           1008
# Spain             1006
# Portugal          1005
# Austria           1005
# Denmark           1004
# Finland           1004
# Lithuania         1002
# Malta              504
# Cyprus             503
# Luxemburg          502
# Name: count, dtype: int64
# Null values: 0
# Type values: object

# %% [markdown]
# ### Show data on respondents nationality

# %%
columns = list(df.columns)
n_columns = list(filter(lambda x: x.startswith('n_'), columns))

for i in n_columns: 
    show_columns_info(i)
# Out:
# n_BELGIUM
# 0    25487
# 1     1082
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_DENMARK
# 0    25566
# 1     1003
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_GERMANY
# 0    25060
# 1     1509
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_GREECE
# 0    25528
# 1     1041
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_SPAIN
# 0    25580
# 1      989
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_FRANCE
# 0    25483
# 1     1086
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_IRELAND
# 0    25614
# 1      955
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_ITALY
# 0    25484
# 1     1085
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_LUXEMBOURG
# 0    26266
# 1      303
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_NETHERLANDS
# 0    25520
# 1     1049
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_PORTUGAL
# 0    25474
# 1     1095
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_UNITED KINGDOM
# 0    26569
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_AUSTRIA
# 0    25569
# 1     1000
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_SWEDEN
# 0    25523
# 1     1046
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_FINLAND
# 0    25546
# 1     1023
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_CYPRUS
# 0    26084
# 1      485
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_CZECH REPUBLIC
# 0    25501
# 1     1068
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_ESTONIA
# 0    25543
# 1     1026
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_HUNGARY
# 0    25522
# 1     1047
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_LATVIA
# 0    25546
# 1     1023
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_LITHUANIA
# 0    25549
# 1     1020
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_MALTA
# 0    26069
# 1      500
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_POLAND
# 0    25493
# 1     1076
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_SLOVAKIA
# 0    25540
# 1     1029
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_SLOVENIA
# 0    25543
# 1     1026
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_BULGARIA
# 0    25518
# 1     1051
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_ROMANIA
# 0    25474
# 1     1095
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_CROATIA
# 0    25539
# 1     1030
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_OTHER COUNTRIES
# 0    26421
# 1      148
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_DK
# 0    26569
# Name: count, dtype: int64
# Null values: 0
# Type values: int64

# %%
df = df.drop(['n_DK'], axis=1)

# %% [markdown]
# ### Age data

# %%
columns = list(df.columns)
age_columns = []

for i in columns:
    if i.startswith('age'):
        age_columns.append(i)

age_columns
# Out:
# ['age', 'age category', 'age large category']

# %% [markdown]
# #### Show information about age data

# %%
for i in age_columns:
    show_columns_info(i)
# Out:
# age
# 60    543
# 65    537
# 70    526
# 58    523
# 68    521
#      ...
# 93      8
# 95      5
# 96      2
# 97      2
# 98      1
# Name: count, Length: 85, dtype: int64
# Null values: 0
# Type values: int64
#
# age category
# 4    12236
# 3     6523
# 2     5417
# 1     2381
# 5       12
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# age large category
# 6    7408
# 5    4828
# 4    4481
# 3    4127
# 2    3332
# 1    2381
# 7      12
# Name: count, dtype: int64
# Null values: 0
# Type values: int64

# %% [markdown]
# #### data to replace

# %%
age_category_map = {1: '15-24',
            2: '25-39',
            3: '40-54',
            4: '55-98',
            5: 'Refusal',}

age_large_category_map = {
    1: '15-24',
    2: '25-34',
    3: '35-44',
    4: '45-54',
    5: '55-64',
    6: '65+',
    7: 'Refusal'}

columns_maps = {
    'age category': age_category_map, 
    'age large category': age_large_category_map
}

# %% [markdown]
# #### replace number data to categorical data in respondents age

# %%
multiple_replace(columns_maps)
# Out:
# age category
# 55-98      12236
# 40-54       6523
# 25-39       5417
# 15-24       2381
# Refusal       12
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# age large category
# 65+        7408
# 55-64      4828
# 45-54      4481
# 35-44      4127
# 25-34      3332
# 15-24      2381
# Refusal      12
# Name: count, dtype: int64
# Null values: 0
# Type values: object

# %% [markdown]
# ### Sport data

# %% [markdown]
# #### show data about sport

# %%
no_sport_columns = ['respondent_serial', 'uniqid', 'tnscntry', 'country', 
                              'isocntry', 'n_', 'age', 'region', 'GENDER', 'DATE OF INTERVIEW', 
                              'TIME OF INTERVIEW', 'DURATION OF INTERVIEW (SECONDS)', 
                              'N OF PERSONS PRESENT DURING INTERVIEW', 'RESPONDENT COOPERATION', 
                              'SIZE OF COMMUNITY', 'LANGUAGE OF INTERVIEW (ALL LANGUAGES)',]

# %%
def filter_columns(col, unnecessary_columns):
    for i in unnecessary_columns:
        if col.startswith(i):
            return False
    return True

# %%
columns = list(df.columns)
act_columns = []

for col in columns:
    if filter_columns(col, no_sport_columns):
        act_columns.append(col)

show_columns(act_columns)
# Out:
# ['respondent_country', 'SPORT ACTIVITY FREQ', 'SPORT ACTIVITY FREQ RECODE']
# ['PHYS ACTIVITY FREQ', 'PHYS ACTIVITY FREQ RECODE', 'VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK']
# ['VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK RECODE', 'VIGOROUS PHYS ACTIVITY - HOW MUCH TIME', 'MODERATE PHYS ACTIVITY - DAYS LAST WEEK']
# ['MODERATE PHYS ACTIVITY - DAYS LAST WEEK RECODE', 'MODERATE PHYS ACTIVITY - HOW MUCH TIME', 'WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK']
# ['WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK RECODE', 'WALKED AT LEAST 10 MINUTES - HOW MUCH TIME', 'TIME SPENT SITTING']
# ['TIME SPENT SITTING RECODE', 'SPORT ACTIVITY VENUE: FITNESS CENTER', 'SPORT ACTIVITY VENUE: SPORTS CLUB']
# ['SPORT ACTIVITY VENUE: SPORTS CENTER', 'SPORT ACTIVITY VENUE: SCHOOL/UNIVERSITY', 'SPORT ACTIVITY VENUE: AT WORK']
# ['SPORT ACTIVITY VENUE: AT HOME', 'SPORT ACTIVITY VENUE: ON THE WAY', 'SPORT ACTIVITY VENUE: PARK/OUTDOORS']
# ['SPORT ACTIVITY VENUE: ELSEWHERE (SPONT)', 'SPORT ACTIVITY VENUE: DK (SPONT)', 'SPORT ACTIVITY REASON: HEALTH IMPROVEMENT']
# ['SPORT ACTIVITY REASON: PHYSICAL APPEARANCE', 'SPORT ACTIVITY REASON: COUNTERACT AGING', 'SPORT ACTIVITY REASON: HAVE FUN']
# ['SPORT ACTIVITY REASON: RELAX', 'SPORT ACTIVITY REASON: BE WITH FRIENDS', 'SPORT ACTIVITY REASON: MAKE ACQUAINTANCES']
# ['SPORT ACTIVITY REASON: MEET OTHER CULTURES', 'SPORT ACTIVITY REASON: PHYSICAL PERFORMANCE', 'SPORT ACTIVITY REASON: FITNESS']
# ['SPORT ACTIVITY REASON: CONTROL WEIGHT', 'SPORT ACTIVITY REASON: SELF-ESTEEM', 'SPORT ACTIVITY REASON: NEW SKILLS']
# ['SPORT ACTIVITY REASON: SPIRIT OF COMPETITION', 'SPORT ACTIVITY REASON: SOCIAL INTEGRATION', 'SPORT ACTIVITY REASON: OTHER (SPONT)']
# ['SPORT ACTIVITY REASON: DK (SPONT)', 'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: STOPPED', 'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: LESS FREQUENTLY']
# ['COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: SAME', 'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: MORE FREQUENTLY', 'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: PLAN MORE AFTER PANDEMIC']
# ['COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: DK (SPONT)', 'SPORT - MANY OPPORTUNITIES IN AREA', 'SPORT - MANY OPPORTUNITIES BY LOCAL SPORTS CLUBS']
# ['SPORT - LOCAL AUTHORITY DOES NOT DO ENOUGH', 'NO SPORT ACTIVITY REASON: NO TIME', 'NO SPORT ACTIVITY REASON: TOO EXPENSIVE']
# ['NO SPORT ACTIVITY REASON: COMPETITIVITY', 'NO SPORT ACTIVITY REASON: NO INFRASTRUCTURE', 'NO SPORT ACTIVITY REASON: DISABILITY/ILLNESS']
# ['NO SPORT ACTIVITY REASON: NO FRIENDS', 'NO SPORT ACTIVITY REASON: FEEL DISCRIMINATED', 'NO SPORT ACTIVITY REASON: NO OPPORTUNITY W SAME GENDER']
# ['NO SPORT ACTIVITY REASON: LACK MOTIVATION', 'NO SPORT ACTIVITY REASON: RISK OF INJURIES', 'NO SPORT ACTIVITY REASON: ALREADY DOING (SPONT)']
# ['NO SPORT ACTIVITY REASON: OTHER (SPONT)', 'NO SPORT ACTIVITY REASON: DK (SPONT)', 'MEMBERSHIP: HEALTH/FITNESS CENTRE']
# ['MEMBERSHIP: SPORT CLUB', 'MEMBERSHIP: SOCIOCULTURAL CLUB', 'MEMBERSHIP: OTHER (SPONT)']
# ['MEMBERSHIP: NOT A MEMBER (SPONT)', 'MEMBERSHIP: DK (SPONT)', 'ATTENTION ON IMPACT OF SPORT ON ENVIRONMENT']
# ['ATTENTION ON IMPACT OF SPORT ON ENVIRONMENT RECODE', 'SUSTAINABILITY ACTION OF SPORT ORG: USE GREEN ENERGY', 'SUSTAINABILITY ACTION OF SPORT ORG: INCREASE ENERGY EFFICIENCY']
# ['SUSTAINABILITY ACTION OF SPORT ORG: SUSTAINABLE TRANSPORTATION', 'SUSTAINABILITY ACTION OF SPORT ORG: CRITERIA FOR FOOD/CATERING', 'SUSTAINABILITY ACTION OF SPORT ORG: REDUCE WASTE']
# ['SUSTAINABILITY ACTION OF SPORT ORG: NONE AS FAR AS KNOWN', 'SUSTAINABILITY ACTION OF SPORT ORG: DK (SPONT)', 'SUPPORT OF GENDER EQUALITY IN SPORT ORG']
# ['KNOW CONTACT TO SPEAK TO IN SPORT ORG WHEN GENDER DISCRIMINATION', 'VOLUNTARY WORK IN SPORT - ENGAGED OR PLANNED NEXT TWO MONTHS']

# %% [markdown]
# ### freq

# %% [markdown]
# #### init freq

# %%
columns = list(df.columns)
freq_columns = []

for i in columns:
    if 'FREQ' in i:
        freq_columns.append(i)

for i in freq_columns:
    show_columns_info(i)
# Out:
# SPORT ACTIVITY FREQ
# 6    11161
# 3     5047
# 5     3563
# 2     3253
# 1     1876
# 4     1642
# 7       27
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# SPORT ACTIVITY FREQ RECODE
# 4    11161
# 2     8300
# 3     5205
# 1     1876
# 5       27
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# PHYS ACTIVITY FREQ
# 6    7145
# 3    5761
# 1    4308
# 2    3991
# 5    3185
# 4    2146
# 7      33
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# PHYS ACTIVITY FREQ RECODE
# 2    9752
# 4    7145
# 3    5331
# 1    4308
# 5      33
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: LESS FREQUENTLY
# 0.0    13778
# 1.0     6536
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: MORE FREQUENTLY
# 0.0    18520
# 1.0     1794
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64

# %%
df = df.drop(columns=['COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: LESS FREQUENTLY',
                      'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: MORE FREQUENTLY'])

columns = list(df.columns)
freq_columns = []

for i in columns:
    if 'FREQ' in i:
        freq_columns.append(i)

for i in freq_columns:
    show_columns_info(i)
# Out:
# SPORT ACTIVITY FREQ
# 6    11161
# 3     5047
# 5     3563
# 2     3253
# 1     1876
# 4     1642
# 7       27
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# SPORT ACTIVITY FREQ RECODE
# 4    11161
# 2     8300
# 3     5205
# 1     1876
# 5       27
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# PHYS ACTIVITY FREQ
# 6    7145
# 3    5761
# 1    4308
# 2    3991
# 5    3185
# 4    2146
# 7      33
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# PHYS ACTIVITY FREQ RECODE
# 2    9752
# 4    7145
# 3    5331
# 1    4308
# 5      33
# Name: count, dtype: int64
# Null values: 0
# Type values: int64

# %% [markdown]
# #### data to replace

# %%
freq_map = {
    1: '5 or > a week',
    2: '3 to 4 a week',
    3: '1 to 2 times a week',
    4: '1 to 3 times a month',
    5: 'Less often',
    6: 'Never',
    7: 'DK (SPONT.)',}

freq_recode_map = {
    1: 'Regularly (1 in SPORT ACTIVITY FREQ)',
    2: 'With some regularity (2 and 3 in SPORT ACTIVITY FREQ)',
    3: 'Seldom (4 and 5 in SPORT ACTIVITY FREQ)',
    4: 'Never',
    5: 'DK (SPONT.)'}

columns_maps = {
    'SPORT ACTIVITY FREQ': freq_map,
    'SPORT ACTIVITY FREQ RECODE': freq_recode_map,
    'PHYS ACTIVITY FREQ': freq_map,
    'PHYS ACTIVITY FREQ RECODE': freq_recode_map,
}

# %% [markdown]
# #### replace number data to categorical data in respondents sport/physical frequency activity

# %%
multiple_replace(columns_maps)
# Out:
# SPORT ACTIVITY FREQ
# Never                   11161
# 1 to 2 times a week      5047
# Less often               3563
# 3 to 4 a week            3253
# 5 or > a week            1876
# 1 to 3 times a month     1642
# DK (SPONT.)                27
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY FREQ RECODE
# Never                                                    11161
# With some regularity (2 and 3 in SPORT ACTIVITY FREQ)     8300
# Seldom (4 and 5 in SPORT ACTIVITY FREQ)                   5205
# Regularly (1 in SPORT ACTIVITY FREQ)                      1876
# DK (SPONT.)                                                 27
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# PHYS ACTIVITY FREQ
# Never                   7145
# 1 to 2 times a week     5761
# 5 or > a week           4308
# 3 to 4 a week           3991
# Less often              3185
# 1 to 3 times a month    2146
# DK (SPONT.)               33
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# PHYS ACTIVITY FREQ RECODE
# With some regularity (2 and 3 in SPORT ACTIVITY FREQ)    9752
# Never                                                    7145
# Seldom (4 and 5 in SPORT ACTIVITY FREQ)                  5331
# Regularly (1 in SPORT ACTIVITY FREQ)                     4308
# DK (SPONT.)                                                33
# Name: count, dtype: int64
# Null values: 0
# Type values: object

# %% [markdown]
# ### Physical Activity (Days & Duration)

# %% [markdown]
# #### init

# %%
columns = list(df.columns)
p_a_columns = []

for i in columns:
    if i.endswith('DAYS LAST WEEK') or i.endswith('DAYS LAST WEEK RECODE') or i.endswith('HOW MUCH TIME'):
        p_a_columns.append(i)

for i in p_a_columns:
    show_columns_info(i)
# Out:
# VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK
# 8.0    6643
# 2.0    3410
# 3.0    2632
# 1.0    2594
# 4.0    1682
# 5.0    1530
# 7.0    1237
# 6.0     561
# 9.0      25
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK RECODE
# 2.0    8636
# 1.0    6643
# 3.0    5010
# 4.0      25
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# VIGOROUS PHYS ACTIVITY - HOW MUCH TIME
# 2.0    6307
# 6.0    4009
# 3.0    3538
# 1.0    3266
# 5.0    1680
# 4.0    1439
# 7.0      75
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# MODERATE PHYS ACTIVITY - DAYS LAST WEEK
# 8.0    4379
# 2.0    3681
# 3.0    3036
# 7.0    2360
# 1.0    2294
# 4.0    1914
# 5.0    1872
# 6.0     728
# 9.0      50
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# MODERATE PHYS ACTIVITY - DAYS LAST WEEK RECODE
# 2.0    9011
# 3.0    6874
# 1.0    4379
# 4.0      50
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# MODERATE PHYS ACTIVITY - HOW MUCH TIME
# 2.0    7359
# 1.0    4291
# 3.0    3422
# 6.0    2094
# 5.0    1609
# 4.0    1456
# 7.0      83
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK
# 7    9043
# 8    3518
# 5    3066
# 3    2962
# 2    2645
# 4    2429
# 1    1502
# 6    1340
# 9      64
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK RECODE
# 3    15878
# 2     7109
# 1     3518
# 4       64
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# WALKED AT LEAST 10 MINUTES - HOW MUCH TIME
# 1    9341
# 2    8919
# 3    3190
# 6    2618
# 4    1185
# 5    1160
# 7     156
# Name: count, dtype: int64
# Null values: 0
# Type values: int64

# %% [markdown]
# #### data to replace

# %%
last_week_map = {
    8: 'None',
    9: 'DK (SPONT.)',
    np.nan: 'DK (SPONT.)'}

last_week_r_map = {
    1: 'Never',
    2: '1-3 days',
    3: '4-7 days',
    4: 'DK (SPONT.)',
    9: 'Inap.',
    np.nan: 'DK (SPONT.)'}

time_map = {
    1: '30 minutes or less',
    2: '31 to 60 minutes',
    3: '61 to 90 minutes',
    4: '91 to 120 minutes',
    5: 'More than 120 minutes',
    6: 'Never do any vigorous physical activity',
    7: 'DK (SPONT.)',
    9: 'Inap. ',
    np.nan: 'DK (SPONT.)'}

columns_maps = {
    'VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK': last_week_map,
    'VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK RECODE': last_week_r_map,
    'VIGOROUS PHYS ACTIVITY - HOW MUCH TIME': time_map,
    'MODERATE PHYS ACTIVITY - DAYS LAST WEEK': last_week_map,
    'MODERATE PHYS ACTIVITY - DAYS LAST WEEK RECODE': last_week_r_map,
    'MODERATE PHYS ACTIVITY - HOW MUCH TIME': time_map,
    'WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK': last_week_map,
    'WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK RECODE': last_week_r_map,
    'WALKED AT LEAST 10 MINUTES - HOW MUCH TIME': time_map
}

# %% [markdown]
# #### replace

# %%
multiple_replace(columns_maps)
# Out:
# VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK
# None           6643
# DK (SPONT.)    6280
# 2.0            3410
# 3.0            2632
# 1.0            2594
# 4.0            1682
# 5.0            1530
# 7.0            1237
# 6.0             561
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK RECODE
# 1-3 days       8636
# Never          6643
# DK (SPONT.)    6280
# 4-7 days       5010
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# VIGOROUS PHYS ACTIVITY - HOW MUCH TIME
# DK (SPONT.)                                6330
# 31 to 60 minutes                           6307
# Never do any vigorous physical activity    4009
# 61 to 90 minutes                           3538
# 30 minutes or less                         3266
# More than 120 minutes                      1680
# 91 to 120 minutes                          1439
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# MODERATE PHYS ACTIVITY - DAYS LAST WEEK
# DK (SPONT.)    6305
# None           4379
# 2.0            3681
# 3.0            3036
# 7.0            2360
# 1.0            2294
# 4.0            1914
# 5.0            1872
# 6.0             728
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# MODERATE PHYS ACTIVITY - DAYS LAST WEEK RECODE
# 1-3 days       9011
# 4-7 days       6874
# DK (SPONT.)    6305
# Never          4379
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# MODERATE PHYS ACTIVITY - HOW MUCH TIME
# 31 to 60 minutes                           7359
# DK (SPONT.)                                6338
# 30 minutes or less                         4291
# 61 to 90 minutes                           3422
# Never do any vigorous physical activity    2094
# More than 120 minutes                      1609
# 91 to 120 minutes                          1456
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK
# 7              9043
# None           3518
# 5              3066
# 3              2962
# 2              2645
# 4              2429
# 1              1502
# 6              1340
# DK (SPONT.)      64
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK RECODE
# 4-7 days       15878
# 1-3 days        7109
# Never           3518
# DK (SPONT.)       64
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# WALKED AT LEAST 10 MINUTES - HOW MUCH TIME
# 30 minutes or less                         9341
# 31 to 60 minutes                           8919
# 61 to 90 minutes                           3190
# Never do any vigorous physical activity    2618
# 91 to 120 minutes                          1185
# More than 120 minutes                      1160
# DK (SPONT.)                                 156
# Name: count, dtype: int64
# Null values: 0
# Type values: object

# %% [markdown]
# ### time sitting

# %% [markdown]
# #### init

# %%
columns = list(df.columns)
t_s_columns = []

for i in columns:
    if i.startswith('TIME SPENT SITTING'):
        t_s_columns.append(i)

for i in t_s_columns:
    show_columns_info(i)
# Out:
# TIME SPENT SITTING
# 5     4035
# 6     3741
# 4     3359
# 7     3285
# 10    3260
# 8     2479
# 9     2035
# 3     1932
# 1     1121
# 2      982
# 11     340
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# TIME SPENT SITTING RECODE
# 2    11135
# 3     7799
# 1     4035
# 4     3260
# 5      340
# Name: count, dtype: int64
# Null values: 0
# Type values: int64

# %% [markdown]
# #### data

# %%
t_map = {
        1: '1 hour or less',
        2: '1 hour 1 minute to 1 hour and 30 minutes',
        3: '1 hour 31 minutes to 2 hours 30 minutes',
        4: '2 hours 31 minutes to 3 hours 30 minutes',
        5: '3 hours 31 minutes to 4 hours 30 minutes',
        6: '4 hours 31 minutes to 5 hours 30 minutes',
        7: '5 hours 31 minutes to 6 hours 30 minutes',
        8: '6 hours 31 minutes to 7 hours 30 minutes',
        9: '7 hours 31 minutes to 8 hours 30 minutes',
        10: 'More than 8 hours and 30 minutes',
        11: 'DK (SPONT.)'}

t_r_map = {
        1: '2h 30min or less',
        2: '2h31min to 5h30min',
        3: '5h31min to 8h30min',
        4: '8h31min or more',
        5: 'DK (SPONT.)'
}

columns_maps = {
    'TIME SPENT SITTING': t_map,
    'TIME SPENT SITTING RECODE': t_r_map
}

# %% [markdown]
# #### replace

# %%
multiple_replace(columns_maps)
# Out:
# TIME SPENT SITTING
# 3 hours 31 minutes to 4 hours 30 minutes    4035
# 4 hours 31 minutes to 5 hours 30 minutes    3741
# 2 hours 31 minutes to 3 hours 30 minutes    3359
# 5 hours 31 minutes to 6 hours 30 minutes    3285
# More than 8 hours and 30 minutes            3260
# 6 hours 31 minutes to 7 hours 30 minutes    2479
# 7 hours 31 minutes to 8 hours 30 minutes    2035
# 1 hour 31 minutes to 2 hours 30 minutes     1932
# 1 hour or less                              1121
# 1 hour 1 minute to 1 hour and 30 minutes     982
# DK (SPONT.)                                  340
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# TIME SPENT SITTING RECODE
# 2h31min to 5h30min    11135
# 5h31min to 8h30min     7799
# 2h 30min or less       4035
# 8h31min or more        3260
# DK (SPONT.)             340
# Name: count, dtype: int64
# Null values: 0
# Type values: object

# %% [markdown]
# ### Other sport question where answers are 0 or 1

# %% [markdown]
# #### init

# %%
columns = list(df.columns)
m_columns = []

for i in columns:
    if i.startswith('MEMBERSHIP'):
        m_columns.append(i)

df = df.drop(columns=m_columns)

# %%
columns = list(df.columns)
start_words = ['SPORT ACTIVITY VENUE', 'SPORT ACTIVITY REASON', 'NO SPORT ACTIVITY REASON']

other_columns = []
for i in columns:
    for word in start_words:
        if i.startswith(word):
            other_columns.append(i)

for i in other_columns:
    show_columns_info(i)
# Out:
# SPORT ACTIVITY VENUE: FITNESS CENTER
# 0.0    17643
# 1.0     2671
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY VENUE: SPORTS CLUB
# 0.0    18423
# 1.0     1891
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY VENUE: SPORTS CENTER
# 0.0    18904
# 1.0     1410
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY VENUE: SCHOOL/UNIVERSITY
# 0.0    19691
# 1.0      623
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY VENUE: AT WORK
# 0.0    17950
# 1.0     2364
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY VENUE: AT HOME
# 0.0    11116
# 1.0     9198
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY VENUE: ON THE WAY
# 0.0    15064
# 1.0     5250
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY VENUE: PARK/OUTDOORS
# 0.0    10921
# 1.0     9393
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY VENUE: ELSEWHERE (SPONT)
# 0.0    20078
# 1.0      236
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY VENUE: DK (SPONT)
# 0.0    20028
# 1.0      286
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY REASON: HEALTH IMPROVEMENT
# 1.0    11203
# 0.0     9111
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY REASON: PHYSICAL APPEARANCE
# 0.0    16264
# 1.0     4050
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY REASON: COUNTERACT AGING
# 0.0    16349
# 1.0     3965
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY REASON: HAVE FUN
# 0.0    15115
# 1.0     5199
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY REASON: RELAX
# 0.0    12840
# 1.0     7474
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY REASON: BE WITH FRIENDS
# 0.0    16591
# 1.0     3723
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY REASON: MAKE ACQUAINTANCES
# 0.0    19254
# 1.0     1060
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY REASON: MEET OTHER CULTURES
# 0.0    19857
# 1.0      457
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY REASON: PHYSICAL PERFORMANCE
# 0.0    15125
# 1.0     5189
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY REASON: FITNESS
# 0.0    11434
# 1.0     8880
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY REASON: CONTROL WEIGHT
# 0.0    14877
# 1.0     5437
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY REASON: SELF-ESTEEM
# 0.0    17670
# 1.0     2644
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY REASON: NEW SKILLS
# 0.0    19002
# 1.0     1312
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY REASON: SPIRIT OF COMPETITION
# 0.0    19234
# 1.0     1080
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY REASON: SOCIAL INTEGRATION
# 0.0    19654
# 1.0      660
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY REASON: OTHER (SPONT)
# 0.0    19891
# 1.0      423
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# SPORT ACTIVITY REASON: DK (SPONT)
# 0.0    19920
# 1.0      394
# Name: count, dtype: int64
# Null values: 6255
# Type values: float64
#
# NO SPORT ACTIVITY REASON: NO TIME
# 0    15840
# 1    10729
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: TOO EXPENSIVE
# 0    23986
# 1     2583
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: COMPETITIVITY
# 0    24031
# 1     2538
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: NO INFRASTRUCTURE
# 0    24964
# 1     1605
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: DISABILITY/ILLNESS
# 0    22134
# 1     4435
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: NO FRIENDS
# 0    24969
# 1     1600
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: FEEL DISCRIMINATED
# 0    26224
# 1      345
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: NO OPPORTUNITY W SAME GENDER
# 0    25902
# 1      667
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: LACK MOTIVATION
# 0    20038
# 1     6531
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: RISK OF INJURIES
# 0    24072
# 1     2497
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: ALREADY DOING (SPONT)
# 0    24263
# 1     2306
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: OTHER (SPONT)
# 0    25767
# 1      802
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: DK (SPONT)
# 0    26062
# 1      507
# Name: count, dtype: int64
# Null values: 0
# Type values: int64

# %% [markdown]
# #### data

# %%
other_map = {np.nan: 'None'}
columns_maps = {
    'SPORT ACTIVITY VENUE: FITNESS CENTER': other_map,
    'SPORT ACTIVITY VENUE: SPORTS CLUB': other_map, 
    'SPORT ACTIVITY VENUE: SPORTS CENTER': other_map,
    'SPORT ACTIVITY VENUE: SCHOOL/UNIVERSITY': other_map,
    'SPORT ACTIVITY VENUE: AT WORK': other_map,
    'SPORT ACTIVITY VENUE: AT HOME': other_map,
    'SPORT ACTIVITY VENUE: ON THE WAY': other_map,
    'SPORT ACTIVITY VENUE: PARK/OUTDOORS': other_map,
    'SPORT ACTIVITY VENUE: ELSEWHERE (SPONT)': other_map,
    'SPORT ACTIVITY VENUE: DK (SPONT)': other_map,
    'SPORT ACTIVITY REASON: HEALTH IMPROVEMENT': other_map,
    'SPORT ACTIVITY REASON: PHYSICAL APPEARANCE': other_map,
    'SPORT ACTIVITY REASON: COUNTERACT AGING': other_map,
    'SPORT ACTIVITY REASON: HAVE FUN': other_map,
    'SPORT ACTIVITY REASON: RELAX': other_map,
    'SPORT ACTIVITY REASON: BE WITH FRIENDS': other_map,
    'SPORT ACTIVITY REASON: MAKE ACQUAINTANCES': other_map,
    'SPORT ACTIVITY REASON: MEET OTHER CULTURES': other_map,
    'SPORT ACTIVITY REASON: PHYSICAL PERFORMANCE': other_map,
    'SPORT ACTIVITY REASON: FITNESS': other_map,
    'SPORT ACTIVITY REASON: CONTROL WEIGHT': other_map,
    'SPORT ACTIVITY REASON: SELF-ESTEEM': other_map,
    'SPORT ACTIVITY REASON: NEW SKILLS': other_map,
    'SPORT ACTIVITY REASON: SPIRIT OF COMPETITION': other_map,
    'SPORT ACTIVITY REASON: SOCIAL INTEGRATION': other_map,
    'SPORT ACTIVITY REASON: OTHER (SPONT)': other_map,
    'SPORT ACTIVITY REASON: DK (SPONT)': other_map,
    'NO SPORT ACTIVITY REASON: NO TIME': other_map,
    'NO SPORT ACTIVITY REASON: TOO EXPENSIVE': other_map,
    'NO SPORT ACTIVITY REASON: COMPETITIVITY': other_map,
    'NO SPORT ACTIVITY REASON: NO INFRASTRUCTURE': other_map,
    'NO SPORT ACTIVITY REASON: DISABILITY/ILLNESS': other_map,
    'NO SPORT ACTIVITY REASON: NO FRIENDS': other_map,
    'NO SPORT ACTIVITY REASON: FEEL DISCRIMINATED': other_map,
    'NO SPORT ACTIVITY REASON: NO OPPORTUNITY W SAME GENDER': other_map,
    'NO SPORT ACTIVITY REASON: LACK MOTIVATION': other_map,
    'NO SPORT ACTIVITY REASON: RISK OF INJURIES': other_map
    ,'NO SPORT ACTIVITY REASON: ALREADY DOING (SPONT)': other_map,
    'NO SPORT ACTIVITY REASON: OTHER (SPONT)': other_map,
    'NO SPORT ACTIVITY REASON: DK (SPONT)': other_map,
}

# %% [markdown]
# #### replace

# %%
multiple_replace(columns_maps)
# Out:
# SPORT ACTIVITY VENUE: FITNESS CENTER
# 0.0     17643
# None     6255
# 1.0      2671
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: SPORTS CLUB
# 0.0     18423
# None     6255
# 1.0      1891
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: SPORTS CENTER
# 0.0     18904
# None     6255
# 1.0      1410
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: SCHOOL/UNIVERSITY
# 0.0     19691
# None     6255
# 1.0       623
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: AT WORK
# 0.0     17950
# None     6255
# 1.0      2364
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: AT HOME
# 0.0     11116
# 1.0      9198
# None     6255
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: ON THE WAY
# 0.0     15064
# None     6255
# 1.0      5250
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: PARK/OUTDOORS
# 0.0     10921
# 1.0      9393
# None     6255
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: ELSEWHERE (SPONT)
# 0.0     20078
# None     6255
# 1.0       236
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: DK (SPONT)
# 0.0     20028
# None     6255
# 1.0       286
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: HEALTH IMPROVEMENT
# 1.0     11203
# 0.0      9111
# None     6255
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: PHYSICAL APPEARANCE
# 0.0     16264
# None     6255
# 1.0      4050
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: COUNTERACT AGING
# 0.0     16349
# None     6255
# 1.0      3965
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: HAVE FUN
# 0.0     15115
# None     6255
# 1.0      5199
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: RELAX
# 0.0     12840
# 1.0      7474
# None     6255
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: BE WITH FRIENDS
# 0.0     16591
# None     6255
# 1.0      3723
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: MAKE ACQUAINTANCES
# 0.0     19254
# None     6255
# 1.0      1060
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: MEET OTHER CULTURES
# 0.0     19857
# None     6255
# 1.0       457
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: PHYSICAL PERFORMANCE
# 0.0     15125
# None     6255
# 1.0      5189
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: FITNESS
# 0.0     11434
# 1.0      8880
# None     6255
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: CONTROL WEIGHT
# 0.0     14877
# None     6255
# 1.0      5437
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: SELF-ESTEEM
# 0.0     17670
# None     6255
# 1.0      2644
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: NEW SKILLS
# 0.0     19002
# None     6255
# 1.0      1312
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: SPIRIT OF COMPETITION
# 0.0     19234
# None     6255
# 1.0      1080
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: SOCIAL INTEGRATION
# 0.0     19654
# None     6255
# 1.0       660
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: OTHER (SPONT)
# 0.0     19891
# None     6255
# 1.0       423
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: DK (SPONT)
# 0.0     19920
# None     6255
# 1.0       394
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# NO SPORT ACTIVITY REASON: NO TIME
# 0    15840
# 1    10729
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: TOO EXPENSIVE
# 0    23986
# 1     2583
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: COMPETITIVITY
# 0    24031
# 1     2538
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: NO INFRASTRUCTURE
# 0    24964
# 1     1605
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: DISABILITY/ILLNESS
# 0    22134
# 1     4435
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: NO FRIENDS
# 0    24969
# 1     1600
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: FEEL DISCRIMINATED
# 0    26224
# 1      345
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: NO OPPORTUNITY W SAME GENDER
# 0    25902
# 1      667
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: LACK MOTIVATION
# 0    20038
# 1     6531
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: RISK OF INJURIES
# 0    24072
# 1     2497
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: ALREADY DOING (SPONT)
# 0    24263
# 1     2306
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: OTHER (SPONT)
# 0    25767
# 1      802
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: DK (SPONT)
# 0    26062
# 1      507
# Name: count, dtype: int64
# Null values: 0
# Type values: int64

# %% [markdown]
# ### Datetime

# %%
show_columns_info('DATE OF INTERVIEW')
# Out:
# DATE OF INTERVIEW
# 8.0     1551
# 9.0     1536
# 10.0    1455
# 11.0    1453
# 12.0    1410
# 19.0    1368
# 17.0    1286
# 22.0    1258
# 15.0    1230
# 18.0    1180
# 16.0    1167
# 13.0    1156
# 20.0    1083
# 5.0      924
# 6.0      918
# 23.0     888
# 4.0      830
# 24.0     815
# 25.0     815
# 14.0     695
# 3.0      654
# 7.0      643
# 21.0     623
# 26.0     552
# 27.0     377
# 28.0     277
# 2.0      228
# 29.0     185
# 1.0        4
# Name: count, dtype: int64
# Null values: 8
# Type values: float64

# %%
df = df.dropna(subset=['DATE OF INTERVIEW'])
df['DATE OF INTERVIEW'].isnull().sum()
# Out:
# np.int64(0)

# %%
date_map = {
            1:	'17-Apr-22',
            2:	'19-Apr-22',
            3:	'20-Apr-22',
            4:	'21-Apr-22',
            5:	'22-Apr-22',
            6:	'23-Apr-22',
            7:	'24-Apr-22',
            8:	'25-Apr-22',
            9:	'26-Apr-22',
            10:	'27-Apr-22',
            11:	'28-Apr-22',
            12:	'29-Apr-22',
            13:	'30-Apr-22',
            14:	'1-May-22',
            15:	'2-May-22',
            16:	'3-May-22',
            17:	'4-May-22',
            18:	'5-May-22',
            19:	'6-May-22',
            20:	'7-May-22',
            21:	'8-May-22',
            22:	'9-May-22',
            23:	'10-May-22',
            24:	'11-May-22',
            25:	'12-May-22',
            26:	'13-May-22',
            27:	'14-May-22',
            28:	'15-May-22',
            29:	'16-May-22',
            30:	'30-Mar-22',
            31:	'31-Dec-08'
}

replace_values('DATE OF INTERVIEW', date_map)
# Out:
# DATE OF INTERVIEW
# 25-Apr-22    1551
# 26-Apr-22    1536
# 27-Apr-22    1455
# 28-Apr-22    1453
# 29-Apr-22    1410
# 6-May-22     1368
# 4-May-22     1286
# 9-May-22     1258
# 2-May-22     1230
# 5-May-22     1180
# 3-May-22     1167
# 30-Apr-22    1156
# 7-May-22     1083
# 22-Apr-22     924
# 23-Apr-22     918
# 10-May-22     888
# 21-Apr-22     830
# 11-May-22     815
# 12-May-22     815
# 1-May-22      695
# 20-Apr-22     654
# 24-Apr-22     643
# 8-May-22      623
# 13-May-22     552
# 14-May-22     377
# 15-May-22     277
# 19-Apr-22     228
# 16-May-22     185
# 17-Apr-22       4
# Name: count, dtype: int64
# Null values: 0
# Type values: object

# %%
df['DATE OF INTERVIEW'] = pd.to_datetime(df['DATE OF INTERVIEW'], errors='coerce', dayfirst=True)
df['DATE OF INTERVIEW'].dtype
# Out:
# C:\Users\denze\AppData\Local\Temp\ipykernel_21416\2688295885.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['DATE OF INTERVIEW'] = pd.to_datetime(df['DATE OF INTERVIEW'], errors='coerce', dayfirst=True)
# dtype('<M8[ns]')

# %%
df['DATE OF INTERVIEW'].value_counts()
# Out:
# DATE OF INTERVIEW
# 2022-04-25    1551
# 2022-04-26    1536
# 2022-04-27    1455
# 2022-04-28    1453
# 2022-04-29    1410
# 2022-05-06    1368
# 2022-05-04    1286
# 2022-05-09    1258
# 2022-05-02    1230
# 2022-05-05    1180
# 2022-05-03    1167
# 2022-04-30    1156
# 2022-05-07    1083
# 2022-04-22     924
# 2022-04-23     918
# 2022-05-10     888
# 2022-04-21     830
# 2022-05-11     815
# 2022-05-12     815
# 2022-05-01     695
# 2022-04-20     654
# 2022-04-24     643
# 2022-05-08     623
# 2022-05-13     552
# 2022-05-14     377
# 2022-05-15     277
# 2022-04-19     228
# 2022-05-16     185
# 2022-04-17       4
# Name: count, dtype: int64

# %% [markdown]
# ### Gender

# %%
show_columns_info('GENDER')
# Out:
# GENDER
# 2    14214
# 1    12329
# 3       18
# Name: count, dtype: int64
# Null values: 0
# Type values: int64

# %%
df = df[df['GENDER'] != 3]
show_columns_info('GENDER')
# Out:
# GENDER
# 2    14214
# 1    12329
# Name: count, dtype: int64
# Null values: 0
# Type values: int64

# %% [markdown]
# ### region

# %% [markdown]
# #### init

# %%
columns = list(df.columns)
r_columns = []

for i in columns:
    if i.startswith('region'):
        r_columns.append(i)

for i in r_columns:
    show_columns_info(i)
# Out:
# region_austria
# 9.0    265
# 8.0    185
# 4.0    152
# 6.0    145
# 3.0     70
# 1.0     58
# 2.0     51
# 5.0     49
# 7.0     30
# Name: count, dtype: int64
# Null values: 25538
# Type values: float64
#
# region_belgium
# 8.0     166
# 2.0     164
# 1.0     143
# 4.0     119
# 9.0     107
# 6.0     107
# 5.0      93
# 3.0      71
# 7.0      57
# 11.0     50
# 10.0     24
# Name: count, dtype: int64
# Null values: 25442
# Type values: float64
#
# region_bulgaria
# 5.0    297
# 6.0    208
# 4.0    168
# 3.0    125
# 2.0    124
# 1.0    117
# Name: count, dtype: int64
# Null values: 25504
# Type values: float64
#
# region_croatia
# 2.0    619
# 1.0    389
# Name: count, dtype: int64
# Null values: 25535
# Type values: float64
#
# region_cyprus
# 1.0    199
# 2.0    144
# 3.0     88
# 4.0     40
# 5.0     32
# Name: count, dtype: int64
# Null values: 26040
# Type values: float64
#
# region_czechia
# 1.0    191
# 6.0    171
# 5.0    143
# 2.0    138
# 3.0    118
# 4.0    117
# 7.0    100
# 8.0     93
# Name: count, dtype: int64
# Null values: 25472
# Type values: float64
#
# region_denmark
# 1.0    293
# 3.0    274
# 4.0    200
# 2.0    143
# 5.0     94
# Name: count, dtype: int64
# Null values: 25539
# Type values: float64
#
# region_germany
# 10.0    247
# 2.0     205
# 9.0     161
# 3.0     132
# 1.0     118
# 13.0    100
# 11.0     93
# 16.0     89
# 7.0      79
# 15.0     66
# 14.0     61
# 4.0      58
# 8.0      56
# 12.0     20
# 6.0      16
# 5.0      10
# Name: count, dtype: int64
# Null values: 25032
# Type values: float64
#
# region_estonia
# 1.0    471
# 5.0    257
# 2.0    120
# 4.0    104
# 3.0     78
# Name: count, dtype: int64
# Null values: 25513
# Type values: float64
#
# region_finland
# 4.0    269
# 3.0    250
# 2.0    243
# 1.0    236
# Name: count, dtype: int64
# Null values: 25545
# Type values: float64
#
# region_france
# 1.0     182
# 18.0    110
# 15.0     77
# 13.0     72
# 6.0      66
# 8.0      63
# 21.0     60
# 20.0     58
# 3.0      52
# 9.0      42
# 12.0     40
# 19.0     39
# 16.0     38
# 2.0      24
# 14.0     24
# 10.0     23
# 11.0     14
# 5.0      10
# 17.0      8
# 4.0       4
# 7.0       2
# Name: count, dtype: int64
# Null values: 25535
# Type values: float64
#
# region_greece
# 1.0     375
# 4.0     200
# 8.0      72
# 7.0      72
# 2.0      64
# 3.0      64
# 10.0     64
# 9.0      47
# 6.0      32
# 5.0      24
# Name: count, dtype: int64
# Null values: 25529
# Type values: float64
#
# region_hungary
# 1.0    311
# 3.0    159
# 2.0    128
# 4.0    124
# 6.0    112
# 5.0     96
# 7.0     95
# Name: count, dtype: int64
# Null values: 25518
# Type values: float64
#
# region_ireland
# 6.0    275
# 5.0    152
# 7.0    119
# 1.0    112
# 4.0    110
# 2.0     90
# 3.0     88
# 8.0     65
# Name: count, dtype: int64
# Null values: 25532
# Type values: float64
#
# region_italy
# 3.0     175
# 5.0     104
# 8.0      96
# 17.0     93
# 1.0      79
# 6.0      78
# 11.0     72
# 13.0     72
# 14.0     64
# 9.0      32
# 4.0      30
# 7.0      29
# 16.0     24
# 12.0     24
# 10.0     16
# 15.0     15
# 2.0      14
# Name: count, dtype: int64
# Null values: 25526
# Type values: float64
#
# region_latvia
# 3.0    270
# 5.0    183
# 4.0    166
# 2.0    158
# 1.0    120
# 6.0    114
# Name: count, dtype: int64
# Null values: 25532
# Type values: float64
#
# region_lithuania
# 1.0     243
# 3.0     216
# 7.0     112
# 4.0     111
# 6.0      88
# 5.0      56
# 2.0      56
# 10.0     40
# 8.0      40
# 9.0      40
# Name: count, dtype: int64
# Null values: 25541
# Type values: float64
#
# region_luxembourg
# 4.0    199
# 1.0    172
# 3.0     76
# 2.0     55
# Name: count, dtype: int64
# Null values: 26041
# Type values: float64
#
# region_malta
# 1.0    504
# Name: count, dtype: int64
# Null values: 26039
# Type values: float64
#
# region_netherlands
# 11.0    180
# 9.0     167
# 8.0     165
# 5.0     130
# 7.0      88
# 4.0      84
# 12.0     66
# 3.0      50
# 2.0      40
# 1.0      32
# 10.0     16
# 6.0      14
# Name: count, dtype: int64
# Null values: 25511
# Type values: float64
#
# region_poland
# 2.0     133
# 4.0     123
# 3.0      92
# 9.0      91
# 12.0     75
# 1.0      68
# 16.0     63
# 5.0      56
# 6.0      54
# 14.0     51
# 10.0     48
# 15.0     40
# 8.0      32
# 11.0     32
# 7.0      31
# 13.0     24
# Name: count, dtype: int64
# Null values: 25530
# Type values: float64
#
# region_portugal
# 1.0    384
# 4.0    268
# 3.0    237
# 5.0     68
# 2.0     48
# Name: count, dtype: int64
# Null values: 25538
# Type values: float64
#
# region_romania
# 3.0    183
# 5.0    143
# 1.0    136
# 4.0    134
# 2.0    130
# 6.0    119
# 7.0    112
# 8.0     96
# Name: count, dtype: int64
# Null values: 25490
# Type values: float64
#
# region_slovenia
# 9.0     250
# 2.0     184
# 4.0     103
# 10.0     98
# 12.0     76
# 1.0      73
# 11.0     64
# 7.0      63
# 6.0      32
# 8.0      30
# 5.0      26
# 3.0      23
# Name: count, dtype: int64
# Null values: 25521
# Type values: float64
#
# region_slovakia
# 2.0    371
# 4.0    257
# 3.0    209
# 1.0    173
# Name: count, dtype: int64
# Null values: 25533
# Type values: float64
#
# region_spain
# 15.0    188
# 12.0    164
# 8.0     132
# 13.0    112
# 1.0      64
# 4.0      48
# 10.0     46
# 9.0      45
# 17.0     38
# 16.0     32
# 7.0      32
# 11.0     24
# 2.0      24
# 14.0     19
# 5.0      16
# 3.0      15
# 6.0       7
# Name: count, dtype: int64
# Null values: 25537
# Type values: float64
#
# region_sweden
# 1.0    421
# 2.0    388
# 3.0    229
# Name: count, dtype: int64
# Null values: 25505
# Type values: float64

# %% [markdown]
# #### show all columns

# %%
show_columns(r_columns)
# Out:
# ['region_austria', 'region_belgium', 'region_bulgaria']
# ['region_croatia', 'region_cyprus', 'region_czechia']
# ['region_denmark', 'region_germany', 'region_estonia']
# ['region_finland', 'region_france', 'region_greece']
# ['region_hungary', 'region_ireland', 'region_italy']
# ['region_latvia', 'region_lithuania', 'region_luxembourg']
# ['region_malta', 'region_netherlands', 'region_poland']
# ['region_portugal', 'region_romania', 'region_slovenia']
# ['region_slovakia', 'region_spain', 'region_sweden']

# %% [markdown]
# #### data

# %%
region_map = {
    8: 'None',
    9: 'DK (SPONT.)',
    np.nan: 'None'
}

columns_maps = {
    'region_austria': region_map,
    'region_belgium': region_map,
    'region_denmark': region_map,
    'region_estonia': region_map,
    'region_finland': region_map,
    'region_france': region_map,
    'region_germany': region_map,
    'region_greece': region_map,
    'region_hungary': region_map,
    'region_ireland': region_map,
    'region_italy': region_map,
    'region_latvia': region_map,
    'region_lithuania': region_map,
    'region_luxembourg': region_map,
    'region_malta': region_map,
    'region_netherlands': region_map,
    'region_poland': region_map,
    'region_portugal': region_map,
    'region_romania': region_map,
    'region_slovenia': region_map,
    'region_slovakia': region_map,
    'region_spain': region_map,
    'region_sweden': region_map,
}

# %% [markdown]
# #### replace

# %%
multiple_replace(columns_maps)
# Out:
# region_austria
# None           25723
# DK (SPONT.)      265
# 4.0              152
# 6.0              145
# 3.0               70
# 1.0               58
# 2.0               51
# 5.0               49
# 7.0               30
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_belgium
# None           25608
# 2.0              164
# 1.0              143
# 4.0              119
# DK (SPONT.)      107
# 6.0              107
# 5.0               93
# 3.0               71
# 7.0               57
# 11.0              50
# 10.0              24
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_denmark
# None    25539
# 1.0       293
# 3.0       274
# 4.0       200
# 2.0       143
# 5.0        94
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_estonia
# None    25513
# 1.0       471
# 5.0       257
# 2.0       120
# 4.0       104
# 3.0        78
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_finland
# None    25545
# 4.0       269
# 3.0       250
# 2.0       243
# 1.0       236
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_france
# None           25598
# 1.0              182
# 18.0             110
# 15.0              77
# 13.0              72
# 6.0               66
# 21.0              60
# 20.0              58
# 3.0               52
# DK (SPONT.)       42
# 12.0              40
# 19.0              39
# 16.0              38
# 2.0               24
# 14.0              24
# 10.0              23
# 11.0              14
# 5.0               10
# 17.0               8
# 4.0                4
# 7.0                2
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_germany
# None           25088
# 10.0             247
# 2.0              205
# DK (SPONT.)      161
# 3.0              132
# 1.0              118
# 13.0             100
# 11.0              93
# 16.0              89
# 7.0               79
# 15.0              66
# 14.0              61
# 4.0               58
# 12.0              20
# 6.0               16
# 5.0               10
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_greece
# None           25601
# 1.0              375
# 4.0              200
# 7.0               72
# 2.0               64
# 3.0               64
# 10.0              64
# DK (SPONT.)       47
# 6.0               32
# 5.0               24
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_hungary
# None    25518
# 1.0       311
# 3.0       159
# 2.0       128
# 4.0       124
# 6.0       112
# 5.0        96
# 7.0        95
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_ireland
# None    25597
# 6.0       275
# 5.0       152
# 7.0       119
# 1.0       112
# 4.0       110
# 2.0        90
# 3.0        88
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_italy
# None           25622
# 3.0              175
# 5.0              104
# 17.0              93
# 1.0               79
# 6.0               78
# 11.0              72
# 13.0              72
# 14.0              64
# DK (SPONT.)       32
# 4.0               30
# 7.0               29
# 16.0              24
# 12.0              24
# 10.0              16
# 15.0              15
# 2.0               14
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_latvia
# None    25532
# 3.0       270
# 5.0       183
# 4.0       166
# 2.0       158
# 1.0       120
# 6.0       114
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_lithuania
# None           25581
# 1.0              243
# 3.0              216
# 7.0              112
# 4.0              111
# 6.0               88
# 5.0               56
# 2.0               56
# 10.0              40
# DK (SPONT.)       40
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_luxembourg
# None    26041
# 4.0       199
# 1.0       172
# 3.0        76
# 2.0        55
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_malta
# None    26039
# 1.0       504
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_netherlands
# None           25676
# 11.0             180
# DK (SPONT.)      167
# 5.0              130
# 7.0               88
# 4.0               84
# 12.0              66
# 3.0               50
# 2.0               40
# 1.0               32
# 10.0              16
# 6.0               14
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_poland
# None           25562
# 2.0              133
# 4.0              123
# 3.0               92
# DK (SPONT.)       91
# 12.0              75
# 1.0               68
# 16.0              63
# 5.0               56
# 6.0               54
# 14.0              51
# 10.0              48
# 15.0              40
# 11.0              32
# 7.0               31
# 13.0              24
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_portugal
# None    25538
# 1.0       384
# 4.0       268
# 3.0       237
# 5.0        68
# 2.0        48
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_romania
# None    25586
# 3.0       183
# 5.0       143
# 1.0       136
# 4.0       134
# 2.0       130
# 6.0       119
# 7.0       112
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_slovenia
# None           25551
# DK (SPONT.)      250
# 2.0              184
# 4.0              103
# 10.0              98
# 12.0              76
# 1.0               73
# 11.0              64
# 7.0               63
# 6.0               32
# 5.0               26
# 3.0               23
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_slovakia
# None    25533
# 2.0       371
# 4.0       257
# 3.0       209
# 1.0       173
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_spain
# None           25669
# 15.0             188
# 12.0             164
# 13.0             112
# 1.0               64
# 4.0               48
# 10.0              46
# DK (SPONT.)       45
# 17.0              38
# 16.0              32
# 7.0               32
# 11.0              24
# 2.0               24
# 14.0              19
# 5.0               16
# 3.0               15
# 6.0                7
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_sweden
# None    25505
# 1.0       421
# 2.0       388
# 3.0       229
# Name: count, dtype: int64
# Null values: 0
# Type values: object

# %% [markdown]
# ### Clear other unneseccary columns

# %%
delete_columns = ['ATTENTION ON IMPACT OF SPORT ON ENVIRONMENT', 'ATTENTION ON IMPACT OF SPORT ON ENVIRONMENT RECODE', 
                  'SUSTAINABILITY ACTION OF SPORT ORG: USE GREEN ENERGY', 'SUSTAINABILITY ACTION OF SPORT ORG: INCREASE ENERGY EFFICIENCY',
                  'SUSTAINABILITY ACTION OF SPORT ORG: SUSTAINABLE TRANSPORTATION', 'SUSTAINABILITY ACTION OF SPORT ORG: CRITERIA FOR FOOD/CATERING',
                  'SUSTAINABILITY ACTION OF SPORT ORG: REDUCE WASTE', 'SUSTAINABILITY ACTION OF SPORT ORG: NONE AS FAR AS KNOWN',
                  'SUSTAINABILITY ACTION OF SPORT ORG: DK (SPONT)', 'SUPPORT OF GENDER EQUALITY IN SPORT ORG',
                  'KNOW CONTACT TO SPEAK TO IN SPORT ORG WHEN GENDER DISCRIMINATION', 'GENDER EQUALITY IN SPORT - FEMALE ROLE MODELS INSPIRING',
                  'GENDER EQUALITY IN SPORT - FOLLOW FEMALE/MALE SPORT EVENLY IN MEDIA', 
                  'GENDER EQUALITY IN SPORT - MORE ATTENTION FOR GENDER BASED VIOLENCE',
                  'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: SAME', 'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: PLAN MORE AFTER PANDEMIC', 'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: DK (SPONT)',
                  'VOLUNTARY WORK IN SPORT - ENGAGED OR PLANNED NEXT TWO MONTHS', 'DURATION OF INTERVIEW (SECONDS) ', 'N OF PERSONS PRESENT DURING INTERVIEW', 
                  'TIME OF INTERVIEW', 'RESPONDENT COOPERATION',
                  'SIZE OF COMMUNITY', 'LANGUAGE OF INTERVIEW (ALL LANGUAGES)',
                  'SPORT - MANY OPPORTUNITIES IN AREA',
                  'SPORT - MANY OPPORTUNITIES BY LOCAL SPORTS CLUBS', 
                  'SPORT - LOCAL AUTHORITY DOES NOT DO ENOUGH',]

df = df.drop(columns=delete_columns, axis=1)
df.shape
# Out:
# (26543, 120)

# %% [markdown]
# ## Feature engneering

# %% [markdown]
# function to create pivot column

# %%
def get_column(row, replace_words, columns):
    values = []
    for col in columns:
        if row[col] == 1:
            c = col.replace(replace_words, '')
            values.append(c)
    if not values:
        return 'None'
    return ', '.join(values)

# %% [markdown]
# ### create nationality column

# %%
columns = list(df.columns)
start_words = 'n_'
n_columns = list(filter(lambda x: x.startswith(start_words), columns))

df['nationality'] = df.apply(lambda row: get_column(row, start_words, n_columns), axis=1)
show_columns_info('nationality')
# Out:
# nationality
# GERMANY                                      1464
# ROMANIA                                      1078
# PORTUGAL                                     1068
# ITALY                                        1065
# POLAND                                       1064
#                                              ...
# SWEDEN, HUNGARY, CROATIA, OTHER COUNTRIES       1
# AUSTRIA, SWEDEN, FINLAND                        1
# AUSTRIA, SWEDEN                                 1
# AUSTRIA, ESTONIA                                1
# LATVIA, SLOVENIA                                1
# Name: count, Length: 144, dtype: int64
# Null values: 0
# Type values: object

# %% [markdown]
# ### create activity venue

# %%
columns = list(df.columns)
start_words = 'SPORT ACTIVITY VENUE: '
s_v_columns = list(filter(lambda x: x.startswith(start_words), columns))

df['sport activity venue'] = df.apply(lambda row: get_column(row, start_words, s_v_columns), axis=1)
show_columns_info('sport activity venue')
# Out:
# sport activity venue
# None                                                                              6247
# AT HOME                                                                           3523
# PARK/OUTDOORS                                                                     3224
# AT HOME, PARK/OUTDOORS                                                            1740
# ON THE WAY                                                                        1200
#                                                                                   ...
# FITNESS CENTER, SPORTS CENTER, SCHOOL/UNIVERSITY, ON THE WAY, PARK/OUTDOORS          1
# SPORTS CLUB, SPORTS CENTER, AT HOME, ON THE WAY                                      1
# FITNESS CENTER, SPORTS CENTER, AT WORK, PARK/OUTDOORS                                1
# SPORTS CLUB, SPORTS CENTER, AT WORK                                                  1
# FITNESS CENTER, SPORTS CLUB, SPORTS CENTER, AT WORK, ON THE WAY, PARK/OUTDOORS       1
# Name: count, Length: 183, dtype: int64
# Null values: 0
# Type values: object

# %% [markdown]
# ### create activity reason

# %%
columns = list(df.columns)
start_words = 'SPORT ACTIVITY REASON: '
s_r_columns = list(filter(lambda x: x.startswith(start_words), columns))

df['sport activity reason'] = df.apply(lambda row: get_column(row, start_words, s_r_columns), axis=1)
show_columns_info('sport activity reason')
# Out:
# sport activity reason
# None                                                                                                                            6247
# HEALTH IMPROVEMENT                                                                                                              1393
# RELAX                                                                                                                            829
# FITNESS                                                                                                                          613
# HEALTH IMPROVEMENT, FITNESS                                                                                                      442
#                                                                                                                                 ...
# HEALTH IMPROVEMENT, HAVE FUN, RELAX, PHYSICAL PERFORMANCE, CONTROL WEIGHT, SELF-ESTEEM                                             1
# HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, COUNTERACT AGING, RELAX, FITNESS, CONTROL WEIGHT, SPIRIT OF COMPETITION                   1
# HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, RELAX, BE WITH FRIENDS, PHYSICAL PERFORMANCE, CONTROL WEIGHT, SPIRIT OF COMPETITION       1
# HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, BE WITH FRIENDS, MEET OTHER CULTURES, PHYSICAL PERFORMANCE                                1
# HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, COUNTERACT AGING, HAVE FUN, BE WITH FRIENDS, FITNESS, SOCIAL INTEGRATION                  1
# Name: count, Length: 2590, dtype: int64
# Null values: 0
# Type values: object

# %% [markdown]
# ### create no activity reason

# %%
columns = list(df.columns)
start_words = 'NO SPORT ACTIVITY REASON: '
n_s_r_columns = list(filter(lambda x: x.startswith(start_words), columns))

df['no sport activity reason'] = df.apply(lambda row: get_column(row, start_words, n_s_r_columns), axis=1)
show_columns_info('no sport activity reason')
# Out:
# no sport activity reason
# NO TIME                                                                                   6376
# DISABILITY/ILLNESS                                                                        2748
# LACK MOTIVATION                                                                           2701
# ALREADY DOING (SPONT)                                                                     2304
# NO TIME, LACK MOTIVATION                                                                  1218
#                                                                                           ...
# NO TIME, TOO EXPENSIVE, COMPETITIVITY, NO FRIENDS, FEEL DISCRIMINATED, LACK MOTIVATION       1
# TOO EXPENSIVE, COMPETITIVITY, NO FRIENDS, LACK MOTIVATION, RISK OF INJURIES                  1
# NO INFRASTRUCTURE, DISABILITY/ILLNESS, NO FRIENDS, LACK MOTIVATION                           1
# TOO EXPENSIVE, COMPETITIVITY, DISABILITY/ILLNESS, NO OPPORTUNITY W SAME GENDER               1
# NO TIME, TOO EXPENSIVE, COMPETITIVITY, FEEL DISCRIMINATED, LACK MOTIVATION                   1
# Name: count, Length: 365, dtype: int64
# Null values: 0
# Type values: object

# %% [markdown]
# ### create another dataframe with less columns and more rows

# %% [markdown]
# #### create new data frame

# %%
df_small = df[['respondent_serial', 'uniqid', 'respondent_country', 'nationality', 
               'age', 'age category', 'age large category', 'SPORT ACTIVITY FREQ', 
               'SPORT ACTIVITY FREQ RECODE', 'PHYS ACTIVITY FREQ', 'PHYS ACTIVITY FREQ RECODE', 
               'VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK', 'VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK RECODE',
               'VIGOROUS PHYS ACTIVITY - HOW MUCH TIME', 'MODERATE PHYS ACTIVITY - DAYS LAST WEEK', 
               'MODERATE PHYS ACTIVITY - DAYS LAST WEEK RECODE', 'MODERATE PHYS ACTIVITY - HOW MUCH TIME', 
               'WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK', 'WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK RECODE',
               'WALKED AT LEAST 10 MINUTES - HOW MUCH TIME', 'TIME SPENT SITTING', 'TIME SPENT SITTING RECODE',
               'sport activity venue', 'sport activity reason', 'no sport activity reason', 'GENDER', 
               'DATE OF INTERVIEW']]

df_small.head()
# Out:
#    respondent_serial    uniqid respondent_country nationality  age  \
# 0                  6  20000001            Austria     AUSTRIA   63
# 1                 12  20000002            Austria     AUSTRIA   48
# 2                 18  20000003            Austria     AUSTRIA   28
# 3                 23  20000004            Austria     AUSTRIA   69
# 4                 27  20000005            Austria     AUSTRIA   54
#
#   age category age large category   SPORT ACTIVITY FREQ  \
# 0        55-98              55-64   1 to 2 times a week
# 1        40-54              45-54         3 to 4 a week
# 2        25-39              25-34   1 to 2 times a week
# 3        55-98                65+  1 to 3 times a month
# 4        40-54              45-54   1 to 2 times a week
#
#                           SPORT ACTIVITY FREQ RECODE    PHYS ACTIVITY FREQ  \
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...         3 to 4 a week
# 1  With some regularity (2 and 3 in SPORT ACTIVIT...         3 to 4 a week
# 2  With some regularity (2 and 3 in SPORT ACTIVIT...   1 to 2 times a week
# 3            Seldom (4 and 5 in SPORT ACTIVITY FREQ)         3 to 4 a week
# 4  With some regularity (2 and 3 in SPORT ACTIVIT...  1 to 3 times a month
#
#    ... WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK  \
# 0  ...                                           5
# 1  ...                                           3
# 2  ...                                           4
# 3  ...                                           4
# 4  ...                                           5
#
#   WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK RECODE  \
# 0                                           4-7 days
# 1                                           1-3 days
# 2                                           4-7 days
# 3                                           4-7 days
# 4                                           4-7 days
#
#   WALKED AT LEAST 10 MINUTES - HOW MUCH TIME  \
# 0                           61 to 90 minutes
# 1                           31 to 60 minutes
# 2                         30 minutes or less
# 3                           31 to 60 minutes
# 4                         30 minutes or less
#
#                          TIME SPENT SITTING TIME SPENT SITTING RECODE  \
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
# 1  4 hours 31 minutes to 5 hours 30 minutes        2h31min to 5h30min
# 2  4 hours 31 minutes to 5 hours 30 minutes        2h31min to 5h30min
# 3  6 hours 31 minutes to 7 hours 30 minutes        5h31min to 8h30min
# 4  5 hours 31 minutes to 6 hours 30 minutes        5h31min to 8h30min
#
#                  sport activity venue  \
# 0  SPORTS CENTER, AT HOME, ON THE WAY
# 1                       PARK/OUTDOORS
# 2       FITNESS CENTER, PARK/OUTDOORS
# 3                       PARK/OUTDOORS
# 4  AT HOME, ON THE WAY, PARK/OUTDOORS
#
#                                sport activity reason  \
# 0  HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, BE WI...
# 1  HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, BE WI...
# 2  PHYSICAL APPEARANCE, COUNTERACT AGING, HAVE FU...
# 3  HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, COUNT...
# 4  HAVE FUN, BE WITH FRIENDS, MAKE ACQUAINTANCES,...
#
#                             no sport activity reason GENDER DATE OF INTERVIEW
# 0  COMPETITIVITY, NO INFRASTRUCTURE, DISABILITY/I...      2        2022-04-20
# 1  COMPETITIVITY, NO FRIENDS, FEEL DISCRIMINATED,...      1        2022-04-20
# 2  NO TIME, TOO EXPENSIVE, NO FRIENDS, NO OPPORTU...      2        2022-04-20
# 3  COMPETITIVITY, NO INFRASTRUCTURE, NO OPPORTUNI...      1        2022-04-20
# 4  TOO EXPENSIVE, NO INFRASTRUCTURE, FEEL DISCRIM...      2        2022-04-20
#
# [5 rows x 27 columns]

# %% [markdown]
# #### explode by nationality

# %%
df_small['nationality'] = df_small['nationality'].str.split(', ')
df_small = df_small.explode('nationality')
df_small.head()
# Out:
# C:\Users\denze\AppData\Local\Temp\ipykernel_21416\1520291714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_small['nationality'] = df_small['nationality'].str.split(', ')
#    respondent_serial    uniqid respondent_country nationality  age  \
# 0                  6  20000001            Austria     AUSTRIA   63
# 1                 12  20000002            Austria     AUSTRIA   48
# 2                 18  20000003            Austria     AUSTRIA   28
# 3                 23  20000004            Austria     AUSTRIA   69
# 4                 27  20000005            Austria     AUSTRIA   54
#
#   age category age large category   SPORT ACTIVITY FREQ  \
# 0        55-98              55-64   1 to 2 times a week
# 1        40-54              45-54         3 to 4 a week
# 2        25-39              25-34   1 to 2 times a week
# 3        55-98                65+  1 to 3 times a month
# 4        40-54              45-54   1 to 2 times a week
#
#                           SPORT ACTIVITY FREQ RECODE    PHYS ACTIVITY FREQ  \
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...         3 to 4 a week
# 1  With some regularity (2 and 3 in SPORT ACTIVIT...         3 to 4 a week
# 2  With some regularity (2 and 3 in SPORT ACTIVIT...   1 to 2 times a week
# 3            Seldom (4 and 5 in SPORT ACTIVITY FREQ)         3 to 4 a week
# 4  With some regularity (2 and 3 in SPORT ACTIVIT...  1 to 3 times a month
#
#    ... WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK  \
# 0  ...                                           5
# 1  ...                                           3
# 2  ...                                           4
# 3  ...                                           4
# 4  ...                                           5
#
#   WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK RECODE  \
# 0                                           4-7 days
# 1                                           1-3 days
# 2                                           4-7 days
# 3                                           4-7 days
# 4                                           4-7 days
#
#   WALKED AT LEAST 10 MINUTES - HOW MUCH TIME  \
# 0                           61 to 90 minutes
# 1                           31 to 60 minutes
# 2                         30 minutes or less
# 3                           31 to 60 minutes
# 4                         30 minutes or less
#
#                          TIME SPENT SITTING TIME SPENT SITTING RECODE  \
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
# 1  4 hours 31 minutes to 5 hours 30 minutes        2h31min to 5h30min
# 2  4 hours 31 minutes to 5 hours 30 minutes        2h31min to 5h30min
# 3  6 hours 31 minutes to 7 hours 30 minutes        5h31min to 8h30min
# 4  5 hours 31 minutes to 6 hours 30 minutes        5h31min to 8h30min
#
#                  sport activity venue  \
# 0  SPORTS CENTER, AT HOME, ON THE WAY
# 1                       PARK/OUTDOORS
# 2       FITNESS CENTER, PARK/OUTDOORS
# 3                       PARK/OUTDOORS
# 4  AT HOME, ON THE WAY, PARK/OUTDOORS
#
#                                sport activity reason  \
# 0  HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, BE WI...
# 1  HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, BE WI...
# 2  PHYSICAL APPEARANCE, COUNTERACT AGING, HAVE FU...
# 3  HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, COUNT...
# 4  HAVE FUN, BE WITH FRIENDS, MAKE ACQUAINTANCES,...
#
#                             no sport activity reason GENDER DATE OF INTERVIEW
# 0  COMPETITIVITY, NO INFRASTRUCTURE, DISABILITY/I...      2        2022-04-20
# 1  COMPETITIVITY, NO FRIENDS, FEEL DISCRIMINATED,...      1        2022-04-20
# 2  NO TIME, TOO EXPENSIVE, NO FRIENDS, NO OPPORTU...      2        2022-04-20
# 3  COMPETITIVITY, NO INFRASTRUCTURE, NO OPPORTUNI...      1        2022-04-20
# 4  TOO EXPENSIVE, NO INFRASTRUCTURE, FEEL DISCRIM...      2        2022-04-20
#
# [5 rows x 27 columns]

# %%
df_small.shape
# Out:
# (26863, 27)

# %% [markdown]
# #### explode by venue

# %%
df_small['sport activity venue'] = df_small['sport activity venue'].str.split(', ')
df_small = df_small.explode('sport activity venue')
df_small.head()
# Out:
#    respondent_serial    uniqid respondent_country nationality  age  \
# 0                  6  20000001            Austria     AUSTRIA   63
# 0                  6  20000001            Austria     AUSTRIA   63
# 0                  6  20000001            Austria     AUSTRIA   63
# 1                 12  20000002            Austria     AUSTRIA   48
# 2                 18  20000003            Austria     AUSTRIA   28
#
#   age category age large category  SPORT ACTIVITY FREQ  \
# 0        55-98              55-64  1 to 2 times a week
# 0        55-98              55-64  1 to 2 times a week
# 0        55-98              55-64  1 to 2 times a week
# 1        40-54              45-54        3 to 4 a week
# 2        25-39              25-34  1 to 2 times a week
#
#                           SPORT ACTIVITY FREQ RECODE   PHYS ACTIVITY FREQ  \
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...        3 to 4 a week
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...        3 to 4 a week
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...        3 to 4 a week
# 1  With some regularity (2 and 3 in SPORT ACTIVIT...        3 to 4 a week
# 2  With some regularity (2 and 3 in SPORT ACTIVIT...  1 to 2 times a week
#
#    ... WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK  \
# 0  ...                                           5
# 0  ...                                           5
# 0  ...                                           5
# 1  ...                                           3
# 2  ...                                           4
#
#   WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK RECODE  \
# 0                                           4-7 days
# 0                                           4-7 days
# 0                                           4-7 days
# 1                                           1-3 days
# 2                                           4-7 days
#
#   WALKED AT LEAST 10 MINUTES - HOW MUCH TIME  \
# 0                           61 to 90 minutes
# 0                           61 to 90 minutes
# 0                           61 to 90 minutes
# 1                           31 to 60 minutes
# 2                         30 minutes or less
#
#                          TIME SPENT SITTING TIME SPENT SITTING RECODE  \
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
# 1  4 hours 31 minutes to 5 hours 30 minutes        2h31min to 5h30min
# 2  4 hours 31 minutes to 5 hours 30 minutes        2h31min to 5h30min
#
#   sport activity venue                              sport activity reason  \
# 0        SPORTS CENTER  HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, BE WI...
# 0              AT HOME  HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, BE WI...
# 0           ON THE WAY  HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, BE WI...
# 1        PARK/OUTDOORS  HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, BE WI...
# 2       FITNESS CENTER  PHYSICAL APPEARANCE, COUNTERACT AGING, HAVE FU...
#
#                             no sport activity reason GENDER DATE OF INTERVIEW
# 0  COMPETITIVITY, NO INFRASTRUCTURE, DISABILITY/I...      2        2022-04-20
# 0  COMPETITIVITY, NO INFRASTRUCTURE, DISABILITY/I...      2        2022-04-20
# 0  COMPETITIVITY, NO INFRASTRUCTURE, DISABILITY/I...      2        2022-04-20
# 1  COMPETITIVITY, NO FRIENDS, FEEL DISCRIMINATED,...      1        2022-04-20
# 2  NO TIME, TOO EXPENSIVE, NO FRIENDS, NO OPPORTU...      2        2022-04-20
#
# [5 rows x 27 columns]

# %%
df_small.shape
# Out:
# (40027, 27)

# %% [markdown]
# #### explode by reason

# %%
df_small['sport activity reason'] = df_small['sport activity reason'].str.split(', ')
df_small = df_small.explode('sport activity reason')
df_small.head()
# Out:
#    respondent_serial    uniqid respondent_country nationality  age  \
# 0                  6  20000001            Austria     AUSTRIA   63
# 0                  6  20000001            Austria     AUSTRIA   63
# 0                  6  20000001            Austria     AUSTRIA   63
# 0                  6  20000001            Austria     AUSTRIA   63
# 0                  6  20000001            Austria     AUSTRIA   63
#
#   age category age large category  SPORT ACTIVITY FREQ  \
# 0        55-98              55-64  1 to 2 times a week
# 0        55-98              55-64  1 to 2 times a week
# 0        55-98              55-64  1 to 2 times a week
# 0        55-98              55-64  1 to 2 times a week
# 0        55-98              55-64  1 to 2 times a week
#
#                           SPORT ACTIVITY FREQ RECODE PHYS ACTIVITY FREQ  ...  \
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...      3 to 4 a week  ...
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...      3 to 4 a week  ...
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...      3 to 4 a week  ...
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...      3 to 4 a week  ...
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...      3 to 4 a week  ...
#
#   WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK  \
# 0                                           5
# 0                                           5
# 0                                           5
# 0                                           5
# 0                                           5
#
#   WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK RECODE  \
# 0                                           4-7 days
# 0                                           4-7 days
# 0                                           4-7 days
# 0                                           4-7 days
# 0                                           4-7 days
#
#   WALKED AT LEAST 10 MINUTES - HOW MUCH TIME  \
# 0                           61 to 90 minutes
# 0                           61 to 90 minutes
# 0                           61 to 90 minutes
# 0                           61 to 90 minutes
# 0                           61 to 90 minutes
#
#                          TIME SPENT SITTING TIME SPENT SITTING RECODE  \
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
#
#   sport activity venue sport activity reason  \
# 0        SPORTS CENTER    HEALTH IMPROVEMENT
# 0        SPORTS CENTER   PHYSICAL APPEARANCE
# 0        SPORTS CENTER       BE WITH FRIENDS
# 0        SPORTS CENTER               FITNESS
# 0        SPORTS CENTER        CONTROL WEIGHT
#
#                             no sport activity reason GENDER DATE OF INTERVIEW
# 0  COMPETITIVITY, NO INFRASTRUCTURE, DISABILITY/I...      2        2022-04-20
# 0  COMPETITIVITY, NO INFRASTRUCTURE, DISABILITY/I...      2        2022-04-20
# 0  COMPETITIVITY, NO INFRASTRUCTURE, DISABILITY/I...      2        2022-04-20
# 0  COMPETITIVITY, NO INFRASTRUCTURE, DISABILITY/I...      2        2022-04-20
# 0  COMPETITIVITY, NO INFRASTRUCTURE, DISABILITY/I...      2        2022-04-20
#
# [5 rows x 27 columns]

# %%
df_small.shape
# Out:
# (125375, 27)

# %% [markdown]
# #### explode by no sport

# %%
df_small['no sport activity reason'] = df_small['no sport activity reason'].str.split(', ')
df_small = df_small.explode('no sport activity reason')
df_small.head()
# Out:
#    respondent_serial    uniqid respondent_country nationality  age  \
# 0                  6  20000001            Austria     AUSTRIA   63
# 0                  6  20000001            Austria     AUSTRIA   63
# 0                  6  20000001            Austria     AUSTRIA   63
# 0                  6  20000001            Austria     AUSTRIA   63
# 0                  6  20000001            Austria     AUSTRIA   63
#
#   age category age large category  SPORT ACTIVITY FREQ  \
# 0        55-98              55-64  1 to 2 times a week
# 0        55-98              55-64  1 to 2 times a week
# 0        55-98              55-64  1 to 2 times a week
# 0        55-98              55-64  1 to 2 times a week
# 0        55-98              55-64  1 to 2 times a week
#
#                           SPORT ACTIVITY FREQ RECODE PHYS ACTIVITY FREQ  ...  \
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...      3 to 4 a week  ...
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...      3 to 4 a week  ...
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...      3 to 4 a week  ...
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...      3 to 4 a week  ...
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...      3 to 4 a week  ...
#
#   WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK  \
# 0                                           5
# 0                                           5
# 0                                           5
# 0                                           5
# 0                                           5
#
#   WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK RECODE  \
# 0                                           4-7 days
# 0                                           4-7 days
# 0                                           4-7 days
# 0                                           4-7 days
# 0                                           4-7 days
#
#   WALKED AT LEAST 10 MINUTES - HOW MUCH TIME  \
# 0                           61 to 90 minutes
# 0                           61 to 90 minutes
# 0                           61 to 90 minutes
# 0                           61 to 90 minutes
# 0                           61 to 90 minutes
#
#                          TIME SPENT SITTING TIME SPENT SITTING RECODE  \
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
#
#   sport activity venue sport activity reason no sport activity reason GENDER  \
# 0        SPORTS CENTER    HEALTH IMPROVEMENT            COMPETITIVITY      2
# 0        SPORTS CENTER    HEALTH IMPROVEMENT        NO INFRASTRUCTURE      2
# 0        SPORTS CENTER    HEALTH IMPROVEMENT       DISABILITY/ILLNESS      2
# 0        SPORTS CENTER   PHYSICAL APPEARANCE            COMPETITIVITY      2
# 0        SPORTS CENTER   PHYSICAL APPEARANCE        NO INFRASTRUCTURE      2
#
#   DATE OF INTERVIEW
# 0        2022-04-20
# 0        2022-04-20
# 0        2022-04-20
# 0        2022-04-20
# 0        2022-04-20
#
# [5 rows x 27 columns]

# %%
df_small.shape
# Out:
# (178132, 27)

# %% [markdown]
# ## Output final data

# %% [markdown]
# ### show final data

# %% [markdown]
# #### full data

# %%
df.head()
# Out:
#    respondent_serial    uniqid respondent_country  n_BELGIUM  n_DENMARK  \
# 0                  6  20000001            Austria          0          0
# 1                 12  20000002            Austria          0          0
# 2                 18  20000003            Austria          0          0
# 3                 23  20000004            Austria          0          0
# 4                 27  20000005            Austria          0          0
#
#    n_GERMANY  n_GREECE  n_SPAIN  n_FRANCE  n_IRELAND  ...  region_portugal  \
# 0          0         0        0         0          0  ...             None
# 1          0         0        0         0          0  ...             None
# 2          0         0        0         0          0  ...             None
# 3          0         0        0         0          0  ...             None
# 4          0         0        0         0          0  ...             None
#
#    region_romania  region_slovenia  region_slovakia  region_spain  \
# 0            None             None             None          None
# 1            None             None             None          None
# 2            None             None             None          None
# 3            None             None             None          None
# 4            None             None             None          None
#
#    region_sweden  nationality                sport activity venue  \
# 0           None      AUSTRIA  SPORTS CENTER, AT HOME, ON THE WAY
# 1           None      AUSTRIA                       PARK/OUTDOORS
# 2           None      AUSTRIA       FITNESS CENTER, PARK/OUTDOORS
# 3           None      AUSTRIA                       PARK/OUTDOORS
# 4           None      AUSTRIA  AT HOME, ON THE WAY, PARK/OUTDOORS
#
#                                sport activity reason  \
# 0  HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, BE WI...
# 1  HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, BE WI...
# 2  PHYSICAL APPEARANCE, COUNTERACT AGING, HAVE FU...
# 3  HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, COUNT...
# 4  HAVE FUN, BE WITH FRIENDS, MAKE ACQUAINTANCES,...
#
#                             no sport activity reason
# 0  COMPETITIVITY, NO INFRASTRUCTURE, DISABILITY/I...
# 1  COMPETITIVITY, NO FRIENDS, FEEL DISCRIMINATED,...
# 2  NO TIME, TOO EXPENSIVE, NO FRIENDS, NO OPPORTU...
# 3  COMPETITIVITY, NO INFRASTRUCTURE, NO OPPORTUNI...
# 4  TOO EXPENSIVE, NO INFRASTRUCTURE, FEEL DISCRIM...
#
# [5 rows x 124 columns]

# %%
show_columns(list(df.columns))
# Out:
# ['respondent_serial', 'uniqid', 'respondent_country']
# ['n_BELGIUM', 'n_DENMARK', 'n_GERMANY']
# ['n_GREECE', 'n_SPAIN', 'n_FRANCE']
# ['n_IRELAND', 'n_ITALY', 'n_LUXEMBOURG']
# ['n_NETHERLANDS', 'n_PORTUGAL', 'n_UNITED KINGDOM']
# ['n_AUSTRIA', 'n_SWEDEN', 'n_FINLAND']
# ['n_CYPRUS', 'n_CZECH REPUBLIC', 'n_ESTONIA']
# ['n_HUNGARY', 'n_LATVIA', 'n_LITHUANIA']
# ['n_MALTA', 'n_POLAND', 'n_SLOVAKIA']
# ['n_SLOVENIA', 'n_BULGARIA', 'n_ROMANIA']
# ['n_CROATIA', 'n_OTHER COUNTRIES', 'age']
# ['age category', 'age large category', 'SPORT ACTIVITY FREQ']
# ['SPORT ACTIVITY FREQ RECODE', 'PHYS ACTIVITY FREQ', 'PHYS ACTIVITY FREQ RECODE']
# ['VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK', 'VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK RECODE', 'VIGOROUS PHYS ACTIVITY - HOW MUCH TIME']
# ['MODERATE PHYS ACTIVITY - DAYS LAST WEEK', 'MODERATE PHYS ACTIVITY - DAYS LAST WEEK RECODE', 'MODERATE PHYS ACTIVITY - HOW MUCH TIME']
# ['WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK', 'WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK RECODE', 'WALKED AT LEAST 10 MINUTES - HOW MUCH TIME']
# ['TIME SPENT SITTING', 'TIME SPENT SITTING RECODE', 'SPORT ACTIVITY VENUE: FITNESS CENTER']
# ['SPORT ACTIVITY VENUE: SPORTS CLUB', 'SPORT ACTIVITY VENUE: SPORTS CENTER', 'SPORT ACTIVITY VENUE: SCHOOL/UNIVERSITY']
# ['SPORT ACTIVITY VENUE: AT WORK', 'SPORT ACTIVITY VENUE: AT HOME', 'SPORT ACTIVITY VENUE: ON THE WAY']
# ['SPORT ACTIVITY VENUE: PARK/OUTDOORS', 'SPORT ACTIVITY VENUE: ELSEWHERE (SPONT)', 'SPORT ACTIVITY VENUE: DK (SPONT)']
# ['SPORT ACTIVITY REASON: HEALTH IMPROVEMENT', 'SPORT ACTIVITY REASON: PHYSICAL APPEARANCE', 'SPORT ACTIVITY REASON: COUNTERACT AGING']
# ['SPORT ACTIVITY REASON: HAVE FUN', 'SPORT ACTIVITY REASON: RELAX', 'SPORT ACTIVITY REASON: BE WITH FRIENDS']
# ['SPORT ACTIVITY REASON: MAKE ACQUAINTANCES', 'SPORT ACTIVITY REASON: MEET OTHER CULTURES', 'SPORT ACTIVITY REASON: PHYSICAL PERFORMANCE']
# ['SPORT ACTIVITY REASON: FITNESS', 'SPORT ACTIVITY REASON: CONTROL WEIGHT', 'SPORT ACTIVITY REASON: SELF-ESTEEM']
# ['SPORT ACTIVITY REASON: NEW SKILLS', 'SPORT ACTIVITY REASON: SPIRIT OF COMPETITION', 'SPORT ACTIVITY REASON: SOCIAL INTEGRATION']
# ['SPORT ACTIVITY REASON: OTHER (SPONT)', 'SPORT ACTIVITY REASON: DK (SPONT)', 'COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: STOPPED']
# ['NO SPORT ACTIVITY REASON: NO TIME', 'NO SPORT ACTIVITY REASON: TOO EXPENSIVE', 'NO SPORT ACTIVITY REASON: COMPETITIVITY']
# ['NO SPORT ACTIVITY REASON: NO INFRASTRUCTURE', 'NO SPORT ACTIVITY REASON: DISABILITY/ILLNESS', 'NO SPORT ACTIVITY REASON: NO FRIENDS']
# ['NO SPORT ACTIVITY REASON: FEEL DISCRIMINATED', 'NO SPORT ACTIVITY REASON: NO OPPORTUNITY W SAME GENDER', 'NO SPORT ACTIVITY REASON: LACK MOTIVATION']
# ['NO SPORT ACTIVITY REASON: RISK OF INJURIES', 'NO SPORT ACTIVITY REASON: ALREADY DOING (SPONT)', 'NO SPORT ACTIVITY REASON: OTHER (SPONT)']
# ['NO SPORT ACTIVITY REASON: DK (SPONT)', 'GENDER', 'DATE OF INTERVIEW']
# ['region_austria', 'region_belgium', 'region_bulgaria']
# ['region_croatia', 'region_cyprus', 'region_czechia']
# ['region_denmark', 'region_germany', 'region_estonia']
# ['region_finland', 'region_france', 'region_greece']
# ['region_hungary', 'region_ireland', 'region_italy']
# ['region_latvia', 'region_lithuania', 'region_luxembourg']
# ['region_malta', 'region_netherlands', 'region_poland']
# ['region_portugal', 'region_romania', 'region_slovenia']
# ['region_slovakia', 'region_spain', 'region_sweden']
# ['nationality', 'sport activity venue', 'sport activity reason']
# ['no sport activity reason']

# %% [markdown]
# ##### columns info

# %%
for i in df.columns:
    show_columns_info(i)
# Out:
# respondent_serial
# 323     17
# 1148    17
# 1364    17
# 630     16
# 52      16
#         ..
# 8614     1
# 8631     1
# 8632     1
# 8633     1
# 8634     1
# Name: count, Length: 5814, dtype: int64
# Null values: 0
# Type values: int64
#
# uniqid
# 150026578    1
# 20000001     1
# 20000002     1
# 20000003     1
# 20000004     1
#             ..
# 20000019     1
# 20000020     1
# 20000021     1
# 20000022     1
# 20000023     1
# Name: count, Length: 26543, dtype: int64
# Null values: 0
# Type values: int64
#
# respondent_country
# Germany           1511
# Belgium           1101
# Czech Republic    1071
# Romania           1053
# Bulgaria          1039
# Sweden            1038
# Netherlands       1032
# Estonia           1030
# Hungary           1025
# Slovenia          1022
# Italy             1017
# Greece            1014
# Poland            1013
# Ireland           1011
# Latvia            1011
# Slovakia          1010
# France            1008
# Croatia           1008
# Spain             1006
# Portugal          1005
# Austria           1005
# Denmark           1004
# Lithuania         1002
# Finland            998
# Malta              504
# Cyprus             503
# Luxemburg          502
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# n_BELGIUM
# 0    25462
# 1     1081
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_DENMARK
# 0    25540
# 1     1003
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_GERMANY
# 0    25034
# 1     1509
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_GREECE
# 0    25502
# 1     1041
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_SPAIN
# 0    25554
# 1      989
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_FRANCE
# 0    25461
# 1     1082
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_IRELAND
# 0    25588
# 1      955
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_ITALY
# 0    25460
# 1     1083
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_LUXEMBOURG
# 0    26240
# 1      303
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_NETHERLANDS
# 0    25494
# 1     1049
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_PORTUGAL
# 0    25448
# 1     1095
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_UNITED KINGDOM
# 0    26543
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_AUSTRIA
# 0    25543
# 1     1000
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_SWEDEN
# 0    25502
# 1     1041
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_FINLAND
# 0    25527
# 1     1016
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_CYPRUS
# 0    26058
# 1      485
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_CZECH REPUBLIC
# 0    25477
# 1     1066
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_ESTONIA
# 0    25517
# 1     1026
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_HUNGARY
# 0    25496
# 1     1047
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_LATVIA
# 0    25522
# 1     1021
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_LITHUANIA
# 0    25523
# 1     1020
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_MALTA
# 0    26043
# 1      500
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_POLAND
# 0    25467
# 1     1076
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_SLOVAKIA
# 0    25514
# 1     1029
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_SLOVENIA
# 0    25517
# 1     1026
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_BULGARIA
# 0    25492
# 1     1051
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_ROMANIA
# 0    25452
# 1     1091
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_CROATIA
# 0    25513
# 1     1030
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# n_OTHER COUNTRIES
# 0    26395
# 1      148
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# age
# 60    542
# 65    537
# 70    526
# 58    523
# 68    521
#      ...
# 93      8
# 95      5
# 96      2
# 97      2
# 98      1
# Name: count, Length: 85, dtype: int64
# Null values: 0
# Type values: int64
#
# age category
# 55-98      12233
# 40-54       6516
# 25-39       5408
# 15-24       2375
# Refusal       11
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# age large category
# 65+        7406
# 55-64      4827
# 45-54      4477
# 35-44      4121
# 25-34      3326
# 15-24      2375
# Refusal      11
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY FREQ
# Never                   11150
# 1 to 2 times a week      5043
# Less often               3559
# 3 to 4 a week            3250
# 5 or > a week            1873
# 1 to 3 times a month     1641
# DK (SPONT.)                27
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY FREQ RECODE
# Never                                                    11150
# With some regularity (2 and 3 in SPORT ACTIVITY FREQ)     8293
# Seldom (4 and 5 in SPORT ACTIVITY FREQ)                   5200
# Regularly (1 in SPORT ACTIVITY FREQ)                      1873
# DK (SPONT.)                                                 27
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# PHYS ACTIVITY FREQ
# Never                   7137
# 1 to 2 times a week     5758
# 5 or > a week           4306
# 3 to 4 a week           3988
# Less often              3180
# 1 to 3 times a month    2141
# DK (SPONT.)               33
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# PHYS ACTIVITY FREQ RECODE
# With some regularity (2 and 3 in SPORT ACTIVITY FREQ)    9746
# Never                                                    7137
# Seldom (4 and 5 in SPORT ACTIVITY FREQ)                  5321
# Regularly (1 in SPORT ACTIVITY FREQ)                     4306
# DK (SPONT.)                                                33
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK
# None           6636
# DK (SPONT.)    6272
# 2.0            3407
# 3.0            2629
# 1.0            2592
# 4.0            1682
# 5.0            1529
# 7.0            1235
# 6.0             561
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK RECODE
# 1-3 days       8628
# Never          6636
# DK (SPONT.)    6272
# 4-7 days       5007
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# VIGOROUS PHYS ACTIVITY - HOW MUCH TIME
# DK (SPONT.)                                6322
# 31 to 60 minutes                           6300
# Never do any vigorous physical activity    4005
# 61 to 90 minutes                           3535
# 30 minutes or less                         3263
# More than 120 minutes                      1679
# 91 to 120 minutes                          1439
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# MODERATE PHYS ACTIVITY - DAYS LAST WEEK
# DK (SPONT.)    6297
# None           4373
# 2.0            3679
# 3.0            3035
# 7.0            2357
# 1.0            2290
# 4.0            1913
# 5.0            1871
# 6.0             728
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# MODERATE PHYS ACTIVITY - DAYS LAST WEEK RECODE
# 1-3 days       9004
# 4-7 days       6869
# DK (SPONT.)    6297
# Never          4373
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# MODERATE PHYS ACTIVITY - HOW MUCH TIME
# 31 to 60 minutes                           7355
# DK (SPONT.)                                6330
# 30 minutes or less                         4284
# 61 to 90 minutes                           3419
# Never do any vigorous physical activity    2092
# More than 120 minutes                      1608
# 91 to 120 minutes                          1455
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK
# 7              9032
# None           3513
# 5              3064
# 3              2960
# 2              2643
# 4              2427
# 1              1501
# 6              1340
# DK (SPONT.)      63
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK RECODE
# 4-7 days       15863
# 1-3 days        7104
# Never           3513
# DK (SPONT.)       63
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# WALKED AT LEAST 10 MINUTES - HOW MUCH TIME
# 30 minutes or less                         9333
# 31 to 60 minutes                           8910
# 61 to 90 minutes                           3187
# Never do any vigorous physical activity    2614
# 91 to 120 minutes                          1185
# More than 120 minutes                      1159
# DK (SPONT.)                                 155
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# TIME SPENT SITTING
# 3 hours 31 minutes to 4 hours 30 minutes    4033
# 4 hours 31 minutes to 5 hours 30 minutes    3735
# 2 hours 31 minutes to 3 hours 30 minutes    3358
# 5 hours 31 minutes to 6 hours 30 minutes    3283
# More than 8 hours and 30 minutes            3253
# 6 hours 31 minutes to 7 hours 30 minutes    2477
# 7 hours 31 minutes to 8 hours 30 minutes    2032
# 1 hour 31 minutes to 2 hours 30 minutes     1930
# 1 hour or less                              1120
# 1 hour 1 minute to 1 hour and 30 minutes     982
# DK (SPONT.)                                  340
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# TIME SPENT SITTING RECODE
# 2h31min to 5h30min    11126
# 5h31min to 8h30min     7792
# 2h 30min or less       4032
# 8h31min or more        3253
# DK (SPONT.)             340
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: FITNESS CENTER
# 0.0     17629
# None     6247
# 1.0      2667
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: SPORTS CLUB
# 0.0     18406
# None     6247
# 1.0      1890
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: SPORTS CENTER
# 0.0     18887
# None     6247
# 1.0      1409
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: SCHOOL/UNIVERSITY
# 0.0     19674
# None     6247
# 1.0       622
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: AT WORK
# 0.0     17934
# None     6247
# 1.0      2362
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: AT HOME
# 0.0     11104
# 1.0      9192
# None     6247
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: ON THE WAY
# 0.0     15053
# None     6247
# 1.0      5243
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: PARK/OUTDOORS
# 0.0     10911
# 1.0      9385
# None     6247
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: ELSEWHERE (SPONT)
# 0.0     20060
# None     6247
# 1.0       236
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY VENUE: DK (SPONT)
# 0.0     20010
# None     6247
# 1.0       286
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: HEALTH IMPROVEMENT
# 1.0     11193
# 0.0      9103
# None     6247
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: PHYSICAL APPEARANCE
# 0.0     16254
# None     6247
# 1.0      4042
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: COUNTERACT AGING
# 0.0     16334
# None     6247
# 1.0      3962
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: HAVE FUN
# 0.0     15100
# None     6247
# 1.0      5196
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: RELAX
# 0.0     12827
# 1.0      7469
# None     6247
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: BE WITH FRIENDS
# 0.0     16576
# None     6247
# 1.0      3720
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: MAKE ACQUAINTANCES
# 0.0     19236
# None     6247
# 1.0      1060
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: MEET OTHER CULTURES
# 0.0     19839
# None     6247
# 1.0       457
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: PHYSICAL PERFORMANCE
# 0.0     15114
# None     6247
# 1.0      5182
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: FITNESS
# 0.0     11426
# 1.0      8870
# None     6247
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: CONTROL WEIGHT
# 0.0     14865
# None     6247
# 1.0      5431
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: SELF-ESTEEM
# 0.0     17656
# None     6247
# 1.0      2640
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: NEW SKILLS
# 0.0     18985
# None     6247
# 1.0      1311
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: SPIRIT OF COMPETITION
# 0.0     19218
# None     6247
# 1.0      1078
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: SOCIAL INTEGRATION
# 0.0     19636
# None     6247
# 1.0       660
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: OTHER (SPONT)
# 0.0     19873
# None     6247
# 1.0       423
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# SPORT ACTIVITY REASON: DK (SPONT)
# 0.0     19902
# None     6247
# 1.0       394
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# COVID-19 IMPACT ON PHYSICAL ACTIVITY/SPORT: STOPPED
# 0.0    17107
# 1.0     3189
# Name: count, dtype: int64
# Null values: 6247
# Type values: float64
#
# NO SPORT ACTIVITY REASON: NO TIME
# 0    15821
# 1    10722
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: TOO EXPENSIVE
# 0    23964
# 1     2579
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: COMPETITIVITY
# 0    24011
# 1     2532
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: NO INFRASTRUCTURE
# 0    24943
# 1     1600
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: DISABILITY/ILLNESS
# 0    22114
# 1     4429
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: NO FRIENDS
# 0    24949
# 1     1594
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: FEEL DISCRIMINATED
# 0    26200
# 1      343
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: NO OPPORTUNITY W SAME GENDER
# 0    25876
# 1      667
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: LACK MOTIVATION
# 0    20025
# 1     6518
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: RISK OF INJURIES
# 0    24049
# 1     2494
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: ALREADY DOING (SPONT)
# 0    24239
# 1     2304
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: OTHER (SPONT)
# 0    25741
# 1      802
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# NO SPORT ACTIVITY REASON: DK (SPONT)
# 0    26036
# 1      507
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# GENDER
# 2    14214
# 1    12329
# Name: count, dtype: int64
# Null values: 0
# Type values: int64
#
# DATE OF INTERVIEW
# 2022-04-25    1547
# 2022-04-26    1535
# 2022-04-28    1453
# 2022-04-27    1452
# 2022-04-29    1410
# 2022-05-06    1364
# 2022-05-04    1286
# 2022-05-09    1258
# 2022-05-02    1230
# 2022-05-05    1180
# 2022-05-03    1166
# 2022-04-30    1155
# 2022-05-07    1083
# 2022-04-22     924
# 2022-04-23     918
# 2022-05-10     887
# 2022-04-21     830
# 2022-05-11     815
# 2022-05-12     815
# 2022-05-01     694
# 2022-04-20     654
# 2022-04-24     643
# 2022-05-08     621
# 2022-05-13     552
# 2022-05-14     377
# 2022-05-15     277
# 2022-04-19     228
# 2022-05-16     185
# 2022-04-17       4
# Name: count, dtype: int64
# Null values: 0
# Type values: datetime64[ns]
#
# region_austria
# None           25723
# DK (SPONT.)      265
# 4.0              152
# 6.0              145
# 3.0               70
# 1.0               58
# 2.0               51
# 5.0               49
# 7.0               30
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_belgium
# None           25608
# 2.0              164
# 1.0              143
# 4.0              119
# DK (SPONT.)      107
# 6.0              107
# 5.0               93
# 3.0               71
# 7.0               57
# 11.0              50
# 10.0              24
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_bulgaria
# 5.0    297
# 6.0    208
# 4.0    168
# 3.0    125
# 2.0    124
# 1.0    117
# Name: count, dtype: int64
# Null values: 25504
# Type values: float64
#
# region_croatia
# 2.0    619
# 1.0    389
# Name: count, dtype: int64
# Null values: 25535
# Type values: float64
#
# region_cyprus
# 1.0    199
# 2.0    144
# 3.0     88
# 4.0     40
# 5.0     32
# Name: count, dtype: int64
# Null values: 26040
# Type values: float64
#
# region_czechia
# 1.0    191
# 6.0    171
# 5.0    143
# 2.0    138
# 3.0    118
# 4.0    117
# 7.0    100
# 8.0     93
# Name: count, dtype: int64
# Null values: 25472
# Type values: float64
#
# region_denmark
# None    25539
# 1.0       293
# 3.0       274
# 4.0       200
# 2.0       143
# 5.0        94
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_germany
# None           25088
# 10.0             247
# 2.0              205
# DK (SPONT.)      161
# 3.0              132
# 1.0              118
# 13.0             100
# 11.0              93
# 16.0              89
# 7.0               79
# 15.0              66
# 14.0              61
# 4.0               58
# 12.0              20
# 6.0               16
# 5.0               10
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_estonia
# None    25513
# 1.0       471
# 5.0       257
# 2.0       120
# 4.0       104
# 3.0        78
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_finland
# None    25545
# 4.0       269
# 3.0       250
# 2.0       243
# 1.0       236
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_france
# None           25598
# 1.0              182
# 18.0             110
# 15.0              77
# 13.0              72
# 6.0               66
# 21.0              60
# 20.0              58
# 3.0               52
# DK (SPONT.)       42
# 12.0              40
# 19.0              39
# 16.0              38
# 2.0               24
# 14.0              24
# 10.0              23
# 11.0              14
# 5.0               10
# 17.0               8
# 4.0                4
# 7.0                2
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_greece
# None           25601
# 1.0              375
# 4.0              200
# 7.0               72
# 2.0               64
# 3.0               64
# 10.0              64
# DK (SPONT.)       47
# 6.0               32
# 5.0               24
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_hungary
# None    25518
# 1.0       311
# 3.0       159
# 2.0       128
# 4.0       124
# 6.0       112
# 5.0        96
# 7.0        95
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_ireland
# None    25597
# 6.0       275
# 5.0       152
# 7.0       119
# 1.0       112
# 4.0       110
# 2.0        90
# 3.0        88
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_italy
# None           25622
# 3.0              175
# 5.0              104
# 17.0              93
# 1.0               79
# 6.0               78
# 11.0              72
# 13.0              72
# 14.0              64
# DK (SPONT.)       32
# 4.0               30
# 7.0               29
# 16.0              24
# 12.0              24
# 10.0              16
# 15.0              15
# 2.0               14
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_latvia
# None    25532
# 3.0       270
# 5.0       183
# 4.0       166
# 2.0       158
# 1.0       120
# 6.0       114
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_lithuania
# None           25581
# 1.0              243
# 3.0              216
# 7.0              112
# 4.0              111
# 6.0               88
# 5.0               56
# 2.0               56
# 10.0              40
# DK (SPONT.)       40
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_luxembourg
# None    26041
# 4.0       199
# 1.0       172
# 3.0        76
# 2.0        55
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_malta
# None    26039
# 1.0       504
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_netherlands
# None           25676
# 11.0             180
# DK (SPONT.)      167
# 5.0              130
# 7.0               88
# 4.0               84
# 12.0              66
# 3.0               50
# 2.0               40
# 1.0               32
# 10.0              16
# 6.0               14
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_poland
# None           25562
# 2.0              133
# 4.0              123
# 3.0               92
# DK (SPONT.)       91
# 12.0              75
# 1.0               68
# 16.0              63
# 5.0               56
# 6.0               54
# 14.0              51
# 10.0              48
# 15.0              40
# 11.0              32
# 7.0               31
# 13.0              24
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_portugal
# None    25538
# 1.0       384
# 4.0       268
# 3.0       237
# 5.0        68
# 2.0        48
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_romania
# None    25586
# 3.0       183
# 5.0       143
# 1.0       136
# 4.0       134
# 2.0       130
# 6.0       119
# 7.0       112
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_slovenia
# None           25551
# DK (SPONT.)      250
# 2.0              184
# 4.0              103
# 10.0              98
# 12.0              76
# 1.0               73
# 11.0              64
# 7.0               63
# 6.0               32
# 5.0               26
# 3.0               23
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_slovakia
# None    25533
# 2.0       371
# 4.0       257
# 3.0       209
# 1.0       173
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_spain
# None           25669
# 15.0             188
# 12.0             164
# 13.0             112
# 1.0               64
# 4.0               48
# 10.0              46
# DK (SPONT.)       45
# 17.0              38
# 16.0              32
# 7.0               32
# 11.0              24
# 2.0               24
# 14.0              19
# 5.0               16
# 3.0               15
# 6.0                7
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# region_sweden
# None    25505
# 1.0       421
# 2.0       388
# 3.0       229
# Name: count, dtype: int64
# Null values: 0
# Type values: object
#
# nationality
# GERMANY                                      1464
# ROMANIA                                      1078
# PORTUGAL                                     1068
# ITALY                                        1065
# POLAND                                       1064
#                                              ...
# SWEDEN, HUNGARY, CROATIA, OTHER COUNTRIES       1
# AUSTRIA, SWEDEN, FINLAND                        1
# AUSTRIA, SWEDEN                                 1
# AUSTRIA, ESTONIA                                1
# LATVIA, SLOVENIA                                1
# Name: count, Length: 144, dtype: int64
# Null values: 0
# Type values: object
#
# sport activity venue
# None                                                                              6247
# AT HOME                                                                           3523
# PARK/OUTDOORS                                                                     3224
# AT HOME, PARK/OUTDOORS                                                            1740
# ON THE WAY                                                                        1200
#                                                                                   ...
# FITNESS CENTER, SPORTS CENTER, SCHOOL/UNIVERSITY, ON THE WAY, PARK/OUTDOORS          1
# SPORTS CLUB, SPORTS CENTER, AT HOME, ON THE WAY                                      1
# FITNESS CENTER, SPORTS CENTER, AT WORK, PARK/OUTDOORS                                1
# SPORTS CLUB, SPORTS CENTER, AT WORK                                                  1
# FITNESS CENTER, SPORTS CLUB, SPORTS CENTER, AT WORK, ON THE WAY, PARK/OUTDOORS       1
# Name: count, Length: 183, dtype: int64
# Null values: 0
# Type values: object
#
# sport activity reason
# None                                                                                                                            6247
# HEALTH IMPROVEMENT                                                                                                              1393
# RELAX                                                                                                                            829
# FITNESS                                                                                                                          613
# HEALTH IMPROVEMENT, FITNESS                                                                                                      442
#                                                                                                                                 ...
# HEALTH IMPROVEMENT, HAVE FUN, RELAX, PHYSICAL PERFORMANCE, CONTROL WEIGHT, SELF-ESTEEM                                             1
# HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, COUNTERACT AGING, RELAX, FITNESS, CONTROL WEIGHT, SPIRIT OF COMPETITION                   1
# HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, RELAX, BE WITH FRIENDS, PHYSICAL PERFORMANCE, CONTROL WEIGHT, SPIRIT OF COMPETITION       1
# HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, BE WITH FRIENDS, MEET OTHER CULTURES, PHYSICAL PERFORMANCE                                1
# HEALTH IMPROVEMENT, PHYSICAL APPEARANCE, COUNTERACT AGING, HAVE FUN, BE WITH FRIENDS, FITNESS, SOCIAL INTEGRATION                  1
# Name: count, Length: 2590, dtype: int64
# Null values: 0
# Type values: object
#
# no sport activity reason
# NO TIME                                                                                   6376
# DISABILITY/ILLNESS                                                                        2748
# LACK MOTIVATION                                                                           2701
# ALREADY DOING (SPONT)                                                                     2304
# NO TIME, LACK MOTIVATION                                                                  1218
#                                                                                           ...
# NO TIME, TOO EXPENSIVE, COMPETITIVITY, NO FRIENDS, FEEL DISCRIMINATED, LACK MOTIVATION       1
# TOO EXPENSIVE, COMPETITIVITY, NO FRIENDS, LACK MOTIVATION, RISK OF INJURIES                  1
# NO INFRASTRUCTURE, DISABILITY/ILLNESS, NO FRIENDS, LACK MOTIVATION                           1
# TOO EXPENSIVE, COMPETITIVITY, DISABILITY/ILLNESS, NO OPPORTUNITY W SAME GENDER               1
# NO TIME, TOO EXPENSIVE, COMPETITIVITY, FEEL DISCRIMINATED, LACK MOTIVATION                   1
# Name: count, Length: 365, dtype: int64
# Null values: 0
# Type values: object

# %% [markdown]
# #### smaller data

# %%
df_small.head()
# Out:
#    respondent_serial    uniqid respondent_country nationality  age  \
# 0                  6  20000001            Austria     AUSTRIA   63
# 0                  6  20000001            Austria     AUSTRIA   63
# 0                  6  20000001            Austria     AUSTRIA   63
# 0                  6  20000001            Austria     AUSTRIA   63
# 0                  6  20000001            Austria     AUSTRIA   63
#
#   age category age large category  SPORT ACTIVITY FREQ  \
# 0        55-98              55-64  1 to 2 times a week
# 0        55-98              55-64  1 to 2 times a week
# 0        55-98              55-64  1 to 2 times a week
# 0        55-98              55-64  1 to 2 times a week
# 0        55-98              55-64  1 to 2 times a week
#
#                           SPORT ACTIVITY FREQ RECODE PHYS ACTIVITY FREQ  ...  \
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...      3 to 4 a week  ...
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...      3 to 4 a week  ...
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...      3 to 4 a week  ...
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...      3 to 4 a week  ...
# 0  With some regularity (2 and 3 in SPORT ACTIVIT...      3 to 4 a week  ...
#
#   WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK  \
# 0                                           5
# 0                                           5
# 0                                           5
# 0                                           5
# 0                                           5
#
#   WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK RECODE  \
# 0                                           4-7 days
# 0                                           4-7 days
# 0                                           4-7 days
# 0                                           4-7 days
# 0                                           4-7 days
#
#   WALKED AT LEAST 10 MINUTES - HOW MUCH TIME  \
# 0                           61 to 90 minutes
# 0                           61 to 90 minutes
# 0                           61 to 90 minutes
# 0                           61 to 90 minutes
# 0                           61 to 90 minutes
#
#                          TIME SPENT SITTING TIME SPENT SITTING RECODE  \
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
# 0  3 hours 31 minutes to 4 hours 30 minutes        2h31min to 5h30min
#
#   sport activity venue sport activity reason no sport activity reason GENDER  \
# 0        SPORTS CENTER    HEALTH IMPROVEMENT            COMPETITIVITY      2
# 0        SPORTS CENTER    HEALTH IMPROVEMENT        NO INFRASTRUCTURE      2
# 0        SPORTS CENTER    HEALTH IMPROVEMENT       DISABILITY/ILLNESS      2
# 0        SPORTS CENTER   PHYSICAL APPEARANCE            COMPETITIVITY      2
# 0        SPORTS CENTER   PHYSICAL APPEARANCE        NO INFRASTRUCTURE      2
#
#   DATE OF INTERVIEW
# 0        2022-04-20
# 0        2022-04-20
# 0        2022-04-20
# 0        2022-04-20
# 0        2022-04-20
#
# [5 rows x 27 columns]

# %%
show_columns(list(df_small.columns))
# Out:
# ['respondent_serial', 'uniqid', 'respondent_country']
# ['nationality', 'age', 'age category']
# ['age large category', 'SPORT ACTIVITY FREQ', 'SPORT ACTIVITY FREQ RECODE']
# ['PHYS ACTIVITY FREQ', 'PHYS ACTIVITY FREQ RECODE', 'VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK']
# ['VIGOROUS PHYS ACTIVITY - DAYS LAST WEEK RECODE', 'VIGOROUS PHYS ACTIVITY - HOW MUCH TIME', 'MODERATE PHYS ACTIVITY - DAYS LAST WEEK']
# ['MODERATE PHYS ACTIVITY - DAYS LAST WEEK RECODE', 'MODERATE PHYS ACTIVITY - HOW MUCH TIME', 'WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK']
# ['WALKED AT LEAST 10 MINUTES - DAYS LAST WEEK RECODE', 'WALKED AT LEAST 10 MINUTES - HOW MUCH TIME', 'TIME SPENT SITTING']
# ['TIME SPENT SITTING RECODE', 'sport activity venue', 'sport activity reason']
# ['no sport activity reason', 'GENDER', 'DATE OF INTERVIEW']

# %% [markdown]
# ### export final data

# %%
df.to_csv('data/sport_activity_data.csv', index=False)
df_small.to_csv('data/sport_activity_data_small.csv', index=False)

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Country

# %%
plt.figure(figsize=(12, 5))
sns.histplot(df['respondent_country'], bins=20, kde=True)
plt.xticks(rotation=90)
plt.title('Country Distribution')
# Out:
# Text(0.5, 1.0, 'Country Distribution')

# %% [markdown]
# ### Age

# %%
order = ['15-24', '25-34', '35-44', '45-54', '55-64', '65+', 'Refusal']

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.histplot(df['age'], bins=20, kde=True)
plt.title('Age Distribution')

plt.subplot(1, 2, 2)
sns.countplot(x='age large category', data=df, order=order)
plt.title('Age Distribution by Large Category')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Nationality

# %%
plt.figure(figsize=(12, 5))
sns.histplot(df_small['nationality'], bins=20, kde=True)
plt.xticks(rotation=90)
plt.title('Nationality Distribution')
# Out:
# Text(0.5, 1.0, 'Nationality Distribution')

# %% [markdown]
# ### Gender

# %%
gender_map = {1: 'Male', 2: 'Female'}
plt.figure(figsize=(8, 5))
sns.countplot(x=df['GENDER'].replace(gender_map))
plt.title('Gender Distribution')
# Out:
# Text(0.5, 1.0, 'Gender Distribution')

# %%
df['GENDER']
# Out:
# 0        2
# 1        1
# 2        2
# 3        1
# 4        2
#         ..
# 26564    1
# 26565    2
# 26566    2
# 26567    2
# 26568    1
# Name: GENDER, Length: 26543, dtype: int64

# %% [markdown]
# ## Analyze hypotheses

# %% [markdown]
# ### Hypothesis 1
# Young respondents (aged 15–24) are more likely to engage in physical activity regularly than older respondents (aged 65+).

# %%
young = df[df['age large category'] == '15-24']
young_total = young.shape[0]
young_req = young[young['PHYS ACTIVITY FREQ RECODE'] == 'Regularly (1 in SPORT ACTIVITY FREQ)'].shape[0]
young_some_req = young[young['PHYS ACTIVITY FREQ RECODE'] == 'With some regularity (2 and 3 in SPORT ACTIVITY FREQ)'].shape[0]
persent_req = (young_req / young_total) * 100
persent_some_req = (young_some_req / young_total) * 100
persent_act = persent_req + persent_some_req

print(f'Young people (15-24) who do phys regularly: {persent_req:.2f}%')
print(f'Young people (15-24) who do phys with some regularity: {persent_some_req:.2f}%')
print(f'Total young people (15-24) who do phys: {persent_act:.2f}%')
# Out:
# Young people (15-24) who do phys regularly: 16.04%
# Young people (15-24) who do phys with some regularity: 46.11%
# Total young people (15-24) who do phys: 62.15%

# %%
old = df[df['age large category'] == '65+']
old_total = old.shape[0]
old_req = old[old['PHYS ACTIVITY FREQ RECODE'] == 'Regularly (1 in SPORT ACTIVITY FREQ)'].shape[0]
old_some_req = old[old['PHYS ACTIVITY FREQ RECODE'] == 'With some regularity (2 and 3 in SPORT ACTIVITY FREQ)'].shape[0]
persent_req = (old_req / old_total) * 100
persent_some_req = (old_some_req / old_total) * 100
persent_act = persent_req + persent_some_req

print(f'Old people (65+) who do phys regularly: {persent_req:.2f}%')
print(f'Old people (65+) who do phys with some regularity: {persent_some_req:.2f}%')
print(f'Total old people (65+) who do phys: {persent_act:.2f}%')
# Out:
# Old people (65+) who do phys regularly: 18.40%
# Old people (65+) who do phys with some regularity: 31.46%
# Total old people (65+) who do phys: 49.86%

# %% [markdown]
# ### Hypothesis 2
# Young respondents (aged 15–24) are more likely to engage in sport activity regularly than older respondents (aged 65+).

# %%
young = df[df['age large category'] == '15-24']
young_total = young.shape[0]
young_req = young[young['SPORT ACTIVITY FREQ RECODE'] == 'Regularly (1 in SPORT ACTIVITY FREQ)'].shape[0]
young_some_req = young[young['SPORT ACTIVITY FREQ RECODE'] == 'With some regularity (2 and 3 in SPORT ACTIVITY FREQ)'].shape[0]
persent_req = (young_req / young_total) * 100
persent_some_req = (young_some_req / young_total) * 100
persent_act = persent_req + persent_some_req

print(f'Young people (15-24) who do sport regularly: {persent_req:.2f}%')
print(f'Young people (15-24) who do sport with some regularity: {persent_some_req:.2f}%')
print(f'Total young people (15-24) who do sport: {persent_act:.2f}%')
# Out:
# Young people (15-24) who do sport regularly: 11.24%
# Young people (15-24) who do sport with some regularity: 54.57%
# Total young people (15-24) who do sport: 65.81%

# %%
old = df[df['age large category'] == '65+']
old_total = old.shape[0]
old_req = old[old['SPORT ACTIVITY FREQ RECODE'] == 'Regularly (1 in SPORT ACTIVITY FREQ)'].shape[0]
old_some_req = old[old['SPORT ACTIVITY FREQ RECODE'] == 'With some regularity (2 and 3 in SPORT ACTIVITY FREQ)'].shape[0]
persent_req = (old_req / old_total) * 100
persent_some_req = (old_some_req / old_total) * 100
persent_act = persent_req + persent_some_req

print(f'Old people (65+) who do sport regularly: {persent_req:.2f}%')
print(f'Old people (65+) who do sport with some regularity: {persent_some_req:.2f}%')
print(f'Total old people (65+) who do sport: {persent_act:.2f}%')
# Out:
# Old people (65+) who do sport regularly: 7.86%
# Old people (65+) who do sport with some regularity: 19.81%
# Total old people (65+) who do sport: 27.67%

# %% [markdown]
# ### Hypothesis 7
# Most respondents who engage in sport do so three times per week.

# %% [markdown]
# ### Hypothesis 8
# The most common reason for engaging in sport is to improve health and fitness, across all demographic groups.

# %%
percentages = df_small['sport activity reason'].value_counts(normalize=True).round(3) * 100
percentages
# Out:
# sport activity reason
# HEALTH IMPROVEMENT       15.9
# FITNESS                  12.9
# RELAX                    10.7
# CONTROL WEIGHT            8.2
# PHYSICAL PERFORMANCE      7.8
# HAVE FUN                  7.8
# PHYSICAL APPEARANCE       6.5
# BE WITH FRIENDS           6.0
# COUNTERACT AGING          6.0
# None                      5.1
# SELF-ESTEEM               4.3
# NEW SKILLS                2.3
# MAKE ACQUAINTANCES        1.8
# SPIRIT OF COMPETITION     1.7
# SOCIAL INTEGRATION        1.2
# MEET OTHER CULTURES       0.9
# OTHER (SPONT)             0.5
# DK (SPONT)                0.4
# Name: proportion, dtype: float64

# %% [markdown]
# ### Hypothesis 9
# Men are more likely to engage in sport to improve physical performance.

# %%
male = df_small[df_small['GENDER'] == 1]['sport activity reason']
percentages = male.value_counts(normalize=True).round(3) * 100
percentages
# Out:
# sport activity reason
# HEALTH IMPROVEMENT       15.4
# FITNESS                  13.1
# RELAX                    10.4
# PHYSICAL PERFORMANCE      8.5
# HAVE FUN                  8.1
# CONTROL WEIGHT            7.6
# BE WITH FRIENDS           6.5
# PHYSICAL APPEARANCE       6.1
# COUNTERACT AGING          5.6
# SELF-ESTEEM               4.4
# None                      4.3
# NEW SKILLS                2.5
# SPIRIT OF COMPETITION     2.4
# MAKE ACQUAINTANCES        1.9
# SOCIAL INTEGRATION        1.4
# MEET OTHER CULTURES       1.0
# OTHER (SPONT)             0.5
# DK (SPONT)                0.4
# Name: proportion, dtype: float64

# %% [markdown]
# ### Hypothesis 10
# Women are more likely to engage in sport for fitness-related reasons than for other motivations.

# %%
female = df_small[df_small['GENDER'] == 2]['sport activity reason']
percentages = female.value_counts(normalize=True).round(3) * 100
percentages
# Out:
# sport activity reason
# HEALTH IMPROVEMENT       16.4
# FITNESS                  12.8
# RELAX                    10.9
# CONTROL WEIGHT            8.8
# HAVE FUN                  7.6
# PHYSICAL PERFORMANCE      7.3
# PHYSICAL APPEARANCE       6.8
# COUNTERACT AGING          6.3
# None                      5.8
# BE WITH FRIENDS           5.6
# SELF-ESTEEM               4.3
# NEW SKILLS                2.1
# MAKE ACQUAINTANCES        1.7
# SPIRIT OF COMPETITION     1.0
# SOCIAL INTEGRATION        1.0
# MEET OTHER CULTURES       0.8
# OTHER (SPONT)             0.5
# DK (SPONT)                0.4
# Name: proportion, dtype: float64

# %% [markdown]
# ### Hypothesis 11
# Younger respondents (aged 15–24) are more motivated by fun and social interaction than other reasons

# %%
young = df_small[df_small['age large category'] == '15-24']['sport activity reason']
percentages = young.value_counts(normalize=True).round(3) * 100
percentages
# Out:
# sport activity reason
# FITNESS                  12.5
# HEALTH IMPROVEMENT       12.2
# HAVE FUN                  9.8
# BE WITH FRIENDS           9.2
# PHYSICAL PERFORMANCE      9.1
# RELAX                     9.1
# PHYSICAL APPEARANCE       8.7
# CONTROL WEIGHT            6.6
# SELF-ESTEEM               5.5
# NEW SKILLS                4.4
# SPIRIT OF COMPETITION     3.9
# MAKE ACQUAINTANCES        2.8
# COUNTERACT AGING          1.5
# SOCIAL INTEGRATION        1.5
# MEET OTHER CULTURES       1.5
# None                      1.3
# DK (SPONT)                0.2
# OTHER (SPONT)             0.1
# Name: proportion, dtype: float64

# %% [markdown]
# ### Hypothesis 12
# Lack of motivation is the most frequently cited barrier across all age groups

# %%
percentages = df_small['no sport activity reason'].value_counts(normalize=True).round(3) * 100
percentages
# Out:
# no sport activity reason
# NO TIME                         30.9
# LACK MOTIVATION                 13.4
# ALREADY DOING (SPONT)           13.0
# DISABILITY/ILLNESS               8.0
# TOO EXPENSIVE                    7.6
# COMPETITIVITY                    6.0
# RISK OF INJURIES                 6.0
# NO INFRASTRUCTURE                4.8
# NO FRIENDS                       4.1
# NO OPPORTUNITY W SAME GENDER     1.9
# OTHER (SPONT)                    1.7
# DK (SPONT)                       1.4
# FEEL DISCRIMINATED               1.0
# Name: proportion, dtype: float64

# %% [markdown]
# ### Hypothesis 14
# Older adults (aged 55+) are more likely to mention health problems or age as reasons for not participating

# %%
old = df_small[(df_small['age large category'] == '55-64') | (df_small['age large category'] == '65+')]['no sport activity reason']
percentages = old.value_counts(normalize=True).round(3) * 100
percentages
# Out:
# no sport activity reason
# NO TIME                         19.0
# DISABILITY/ILLNESS              15.3
# LACK MOTIVATION                 15.1
# ALREADY DOING (SPONT)           11.9
# RISK OF INJURIES                 9.3
# COMPETITIVITY                    7.9
# TOO EXPENSIVE                    6.2
# NO INFRASTRUCTURE                4.6
# NO FRIENDS                       3.6
# OTHER (SPONT)                    2.6
# DK (SPONT)                       2.1
# NO OPPORTUNITY W SAME GENDER     1.8
# FEEL DISCRIMINATED               0.6
# Name: proportion, dtype: float64

# %%
percentages = df['SPORT ACTIVITY FREQ'].value_counts(normalize=True).round(3) * 100
percentages
# Out:
# SPORT ACTIVITY FREQ
# Never                   42.0
# 1 to 2 times a week     19.0
# Less often              13.4
# 3 to 4 a week           12.2
# 5 or > a week            7.1
# 1 to 3 times a month     6.2
# DK (SPONT.)              0.1
# Name: proportion, dtype: float64
